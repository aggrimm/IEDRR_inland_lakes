# %% [markdown]
# <a href="https://colab.research.google.com/github/GreatLakesCommission/IEDRR_inland_lakes/blob/main/1_get_spp_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Script to request, QA/QC and combine invasive species observations from several sources.
# Run the setup blocks, the blocks for the sources you want to pull from, then the combine block.
#
# Requesting data from GBIF and EDDMapS requires that you have an account with them.
#
#
# *   To use the GBIF code block, add your GBIF username and password and an email address for notifications to Secrets in your copy of this notebook as GBIF_USER, GBIF_PWD and GBIF_EMAIL.
# *   To use the EDDMaps block, add your account credentials as EDDMAPS_USER and EDDMAPS_PWD.

# %% [markdown]
# # Setup Blocks

# %%
# general setup
# %%capture
from google.colab import drive
drive.mount('/content/drive')
import datetime
import os
os.chdir("drive/My Drive/iedrr")
today = datetime.date.today().strftime('%Y%m%d')
outfolder = "speciesobs_"+today
if not os.path.exists(outfolder):
  os.mkdir(outfolder)
os.chdir(outfolder)
import pandas as pd
# !pip install pyreadr
import pyreadr
from scipy import spatial
from google.colab import userdata

# %%
# run for bounding box containing the Great Lakes states or for the states themselves?
extent = "states" # options: states, box

# invasive species of interest, scientific names are formatted as lists to make it
# possible to include alternate names where more than one is in use across the
# regional databases

fishlist = [
    [['Channa'], 'Snakeheads'],
    [['Clarias batrachus'], 'Walking catfish'],
    [['Gymnocephalus cernua'], 'Ruffe'],
    [['Misgurnus anguillicaudatus'], 'Pond loach'],
    [['Neogobius melanostomus'], 'Round goby'],
    [['Osmerus mordax'], 'Rainbow smelt'],
    [['Osteoglossum bicirrhosum'], 'Silver arowana'],
    [['Proterorhinus semilunaris'], 'Tubenose goby'],
    [['Tinca tinca'], 'Tench'],
]

plantlist = [
    [['Alternanthera philoxeroides'], 'Alligator weed'],
    [['Cabomba caroliniana'], 'Carolina fanwort'],
    [['Callitriche stagnalis'], 'Pond water-starwort'],
    [['Elodea densa', 'Egeria densa'], 'Brazilian waterweed'],
    [['Hottonia palustris'], 'Water violet'],
    [['Hydrilla verticillata'], 'Hydrilla'],
    [['Hydrocharis morsus-ranae'], 'European frog-bit'],
    [['Hygrophila polysperma'], 'Indian swampweed'],
    [['Limnophila sessiliflora'], 'Dwarf ambulia'],
    [['Ludwigia grandiflora'], 'Large-flower primrose-willow'],
    [['Ludwigia hexapetala'], 'Six petal water primrose'],
    [['Ludwigia peploides'], 'Creeping water primrose'],
    [['Marsilea mutica'], 'Australian water-clover'],
    [['Marsilea quadrifolia'], 'European water-clover'],
    [['Myriophyllum aquaticum'], 'Parrot feather'],
    [['Najas minor'], 'Brittle naiad'],
    [['Nasturtium officinale'], 'Water-cress'],
    [['Nelumbo nucifera'], 'Sacred lotus'],
    [['Nitellopsis obtusa'], 'Starry stonewort'],
    [['Ottelia alismoides'], 'Duck-lettuce'],
    [['Pistia stratiotes'], 'Water lettuce'],
    [['Pontederia azurea', 'Eichhornia azurea'], 'Anchored water-hyacinth'],
    [['Pontederia crassipes', 'Eichhornia crassipes'],'Common water-hyacinth'],
    [['Sagittaria sagittifolia'], 'Hawaii arrowhead'],
    [['Salvinia auriculata'], 'Eared salvinia'],
    [['Salvinia molesta'], 'Giant salvinia'],
    [['Spirodela punctata'], 'Dotted duckweed'],
    [['Stratiotes aloides'], 'Water soldier'],
    [['Trapa natans'], 'European water chestnut']
]


# plantlist_slim doesn't include emergent species
plantlist_slim = [
    [['Cabomba caroliniana'], 'Carolina fanwort'],
    [['Callitriche stagnalis'], 'Pond water-starwort'],
    [['Elodea densa', 'Egeria densa'], 'Brazilian waterweed'],
    [['Hydrilla verticillata'], 'Hydrilla'],
    [['Hydrocharis morsus-ranae'], 'European frog-bit'],
    [['Hygrophila polysperma'], 'Indian swampweed'],
    [['Limnophila sessiliflora'], 'Dwarf ambulia'],
    [['Marsilea mutica'], 'Australian water-clover'],
    [['Marsilea quadrifolia'], 'European water-clover'],
    [['Myriophyllum aquaticum'], 'Parrot feather'],
    [['Najas minor'], 'Brittle naiad'],
    [['Nelumbo nucifera'], 'Sacred lotus'],
    [['Nitellopsis obtusa'], 'Starry stonewort'],
    [['Ottelia alismoides'], 'Duck-lettuce'],
    [['Pistia stratiotes'], 'Water lettuce'],
    [['Pontederia azurea', 'Eichhornia azurea'], 'Anchored water-hyacinth'],
    [['Pontederia crassipes', 'Eichhornia crassipes'],'Common water-hyacinth'],
    [['Sagittaria sagittifolia'], 'Hawaii arrowhead'],
    [['Salvinia auriculata'], 'Eared salvinia'],
    [['Salvinia molesta'], 'Giant salvinia'],
    [['Spirodela punctata'], 'Dotted duckweed'],
    [['Stratiotes aloides'], 'Water soldier'],
    [['Trapa natans'], 'European water chestnut']
]

invertlist = [
    [['Bithynia tentaculata'], 'Faucet snail'],
    [['Bythotrephes longimanus'], 'Spiny water flea'],
    [['Cercopagis pengoi'], 'Fishhook waterflea'],
    [['Corbicula fluminea'], 'Basket clam'],
    [['Dreissena bugensis'], 'Quagga mussel'],
    [['Dreissena polymorpha'], 'Zebra mussel'],
    [['Eriocheir sinensis'], 'Mitten crab'],
    [['Hemimysis anomala'], 'Bloody red shrimp'],
    [['Melanoides tuberculata'], 'Red-rimmed melania'],
    [['Potamopyrgus antipodarum'], 'New Zealand mud snail'],
    [['Procambarus virginalis'],'Marbled crayfish (Marmorkrebs)']
]



fishlist = pd.DataFrame(fishlist, columns=['sci_name', 'common_name'])
plantlist = pd.DataFrame(plantlist, columns=['sci_name', 'common_name'])
plantlist_slim = pd.DataFrame(plantlist_slim, columns=['sci_name', 'common_name'])
invertlist = pd.DataFrame(invertlist, columns=['sci_name', 'common_name'])

fishlist['taxon'] = 'fish'
plantlist['taxon'] = 'plant'
plantlist_slim['taxon'] = 'plant'
invertlist['taxon'] = 'invertebrate'



my_vars = {}

my_vars["fish"] = fishlist
my_vars["plant"] = plantlist
my_vars["invert"] = invertlist


# get institution lat/longs for QAQC
url = "https://github.com/ropensci/CoordinateCleaner/raw/refs/heads/master/data/institutions.rda"
dst_path = os.path.join(os.getcwd(), "institutions.rda") # download to CoLab
res = pyreadr.read_r(pyreadr.download_file(url, dst_path)) # convert rda to dictionary of dataframes

institutions = res["institutions"]
# filter to institutions within GL bounding box
institutions = institutions[(institutions['decimalLatitude'].between(36.9171,49.6117)) & (institutions['decimalLongitude'].between(-100.5513,-71.79))]
# set up a k-dimensional tree
inst_coords = list(zip(institutions["decimalLatitude"], institutions["decimalLongitude"]))
tree = spatial.KDTree(inst_coords)

def calculate_min(row):
    return tree.query([(row["lat_dec"],row["lon_dec"])])[0][0]

# !rm institutions.rda

# %% [markdown]
# # GBIF

# %%
#GBIF setup
# !pip list
# !pip install pygbif
# capture suppresses output
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.6
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.4
# ale-py                             0.10.2
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.1
# astropy-iers-data                  0.2025.2.17.0.34.13
# astunparse                         1.6.3
# atpublic                           4.1.0
# attrs                              25.1.0
# audioread                          3.0.1
# autograd                           1.7.0
# babel                              2.17.0
# backcall                           0.2.0
# beautifulsoup4                     4.13.3
# betterproto                        2.0.0b6
# bigframes                          1.37.0
# bigquery-magics                    0.6.0
# bleach                             6.2.0
# blinker                            1.9.0
# blis                               0.7.11
# blosc2                             3.1.1
# bokeh                              3.6.3
# Bottleneck                         1.4.2
# bqplot                             0.12.44
# branca                             0.8.1
# CacheControl                       0.14.2
# cachetools                         5.5.1
# catalogue                          2.0.10
# certifi                            2025.1.31
# cffi                               1.17.1
# chardet                            5.2.0
# charset-normalizer                 3.4.1
# chex                               0.1.88
# clarabel                           0.10.0
# click                              8.1.8
# cloudpathlib                       0.20.0
# cloudpickle                        3.1.1
# cmake                              3.31.4
# cmdstanpy                          1.2.5
# colorcet                           3.1.0
# colorlover                         0.3.0
# colour                             0.1.5
# community                          1.0.0b1
# confection                         0.1.5
# cons                               0.4.6
# contourpy                          1.3.1
# cramjam                            2.9.1
# cryptography                       43.0.3
# cuda-python                        12.6.0
# cudf-cu12                          24.12.0
# cufflinks                          0.17.3
# cupy-cuda12x                       13.3.0
# cvxopt                             1.3.2
# cvxpy                              1.6.0
# cycler                             0.12.1
# cyipopt                            1.5.0
# cymem                              2.0.11
# Cython                             3.0.12
# dask                               2024.10.0
# datascience                        0.17.6
# db-dtypes                          1.4.1
# dbus-python                        1.2.18
# debugpy                            1.8.0
# decorator                          4.4.2
# defusedxml                         0.7.1
# Deprecated                         1.2.18
# diffusers                          0.32.2
# distro                             1.9.0
# dlib                               19.24.2
# dm-tree                            0.1.9
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.21.2
# dopamine_rl                        4.1.2
# duckdb                             1.1.3
# earthengine-api                    1.5.3
# easydict                           1.13
# editdistance                       0.8.1
# eerepr                             0.1.1
# einops                             0.8.1
# en-core-web-sm                     3.7.1
# entrypoints                        0.4
# et_xmlfile                         2.0.0
# etils                              1.12.0
# etuples                            0.3.9
# Farama-Notifications               0.0.4
# fastai                             2.7.18
# fastcore                           1.7.29
# fastdownload                       0.0.7
# fastjsonschema                     2.21.1
# fastprogress                       1.0.3
# fastrlock                          0.8.3
# filelock                           3.17.0
# firebase-admin                     6.6.0
# Flask                              3.1.0
# flatbuffers                        25.2.10
# flax                               0.10.3
# folium                             0.19.4
# fonttools                          4.56.0
# frozendict                         2.4.6
# frozenlist                         1.5.0
# fsspec                             2024.10.0
# future                             1.0.0
# gast                               0.6.0
# gcsfs                              2024.10.0
# GDAL                               3.6.4
# gdown                              5.2.0
# geemap                             0.35.1
# gensim                             4.3.3
# geocoder                           1.38.1
# geographiclib                      2.0
# geopandas                          1.0.1
# geopy                              2.4.1
# gin-config                         0.5.0
# gitdb                              4.0.12
# GitPython                          3.1.44
# glob2                              0.7
# google                             2.0.3
# google-ai-generativelanguage       0.6.15
# google-api-core                    2.24.1
# google-api-python-client           2.160.0
# google-auth                        2.27.0
# google-auth-httplib2               0.2.0
# google-auth-oauthlib               1.2.1
# google-cloud-aiplatform            1.79.0
# google-cloud-bigquery              3.29.0
# google-cloud-bigquery-connection   1.18.0
# google-cloud-bigquery-storage      2.28.0
# google-cloud-bigtable              2.28.1
# google-cloud-core                  2.4.1
# google-cloud-dataproc              5.17.0
# google-cloud-datastore             2.20.2
# google-cloud-firestore             2.20.0
# google-cloud-functions             1.19.0
# google-cloud-iam                   2.18.0
# google-cloud-language              2.16.0
# google-cloud-pubsub                2.25.0
# google-cloud-resource-manager      1.14.0
# google-cloud-spanner               3.51.0
# google-cloud-storage               2.19.0
# google-cloud-translate             3.19.0
# google-colab                       1.0.0
# google-crc32c                      1.6.0
# google-genai                       0.8.0
# google-generativeai                0.8.4
# google-pasta                       0.2.0
# google-resumable-media             2.7.2
# google-spark-connect               0.5.2
# googleapis-common-protos           1.67.0
# googledrivedownloader              1.1.0
# graphviz                           0.20.3
# greenlet                           3.1.1
# grpc-google-iam-v1                 0.14.0
# grpc-interceptor                   0.15.4
# grpcio                             1.70.0
# grpcio-status                      1.62.3
# grpclib                            0.4.7
# gspread                            6.1.4
# gspread-dataframe                  4.0.0
# gym                                0.25.2
# gym-notices                        0.0.8
# gymnasium                          1.0.0
# h11                                0.14.0
# h2                                 4.2.0
# h5netcdf                           1.5.0
# h5py                               3.12.1
# highspy                            1.9.0
# holidays                           0.67
# holoviews                          1.20.1
# hpack                              4.1.0
# html5lib                           1.1
# httpcore                           1.0.7
# httpimport                         1.4.0
# httplib2                           0.22.0
# httpx                              0.28.1
# huggingface-hub                    0.28.1
# humanize                           4.11.0
# hyperframe                         6.1.0
# hyperopt                           0.2.7
# ibis-framework                     9.2.0
# idna                               3.10
# imageio                            2.37.0
# imageio-ffmpeg                     0.6.0
# imagesize                          1.4.1
# imbalanced-learn                   0.13.0
# imgaug                             0.4.0
# immutabledict                      4.2.1
# importlib_metadata                 8.6.1
# importlib_resources                6.5.2
# imutils                            0.5.4
# inflect                            7.5.0
# iniconfig                          2.0.0
# intel-cmplr-lib-ur                 2025.0.4
# intel-openmp                       2025.0.4
# ipyevents                          2.0.2
# ipyfilechooser                     0.6.0
# ipykernel                          6.17.1
# ipyleaflet                         0.19.2
# ipyparallel                        8.8.0
# ipython                            7.34.0
# ipython-genutils                   0.2.0
# ipython-sql                        0.5.0
# ipytree                            0.2.2
# ipywidgets                         7.7.1
# itsdangerous                       2.2.0
# jax                                0.4.33
# jax-cuda12-pjrt                    0.4.33
# jax-cuda12-plugin                  0.4.33
# jaxlib                             0.4.33
# jeepney                            0.7.1
# jellyfish                          1.1.0
# jieba                              0.42.1
# Jinja2                             3.1.5
# jiter                              0.8.2
# joblib                             1.4.2
# jsonpatch                          1.33
# jsonpickle                         4.0.2
# jsonpointer                        3.0.0
# jsonschema                         4.23.0
# jsonschema-specifications          2024.10.1
# jupyter-client                     6.1.12
# jupyter-console                    6.1.0
# jupyter_core                       5.7.2
# jupyter-leaflet                    0.19.2
# jupyter-server                     1.24.0
# jupyterlab_pygments                0.3.0
# jupyterlab_widgets                 3.0.13
# kaggle                             1.6.17
# kagglehub                          0.3.9
# keras                              3.8.0
# keras-hub                          0.18.1
# keras-nlp                          0.18.1
# keyring                            23.5.0
# kiwisolver                         1.4.8
# langchain                          0.3.19
# langchain-core                     0.3.37
# langchain-text-splitters           0.3.6
# langcodes                          3.5.0
# langsmith                          0.3.8
# language_data                      1.3.0
# launchpadlib                       1.10.16
# lazr.restfulclient                 0.14.4
# lazr.uri                           1.0.6
# lazy_loader                        0.4
# libclang                           18.1.1
# libcudf-cu12                       24.12.0
# libkvikio-cu12                     24.12.1
# librosa                            0.10.2.post1
# lightgbm                           4.5.0
# linkify-it-py                      2.0.3
# llvmlite                           0.44.0
# locket                             1.0.0
# logical-unification                0.4.6
# lxml                               5.3.1
# marisa-trie                        1.2.1
# Markdown                           3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         3.0.2
# matplotlib                         3.10.0
# matplotlib-inline                  0.1.7
# matplotlib-venn                    1.1.1
# mdit-py-plugins                    0.4.2
# mdurl                              0.1.2
# miniKanren                         1.0.3
# missingno                          0.5.2
# mistune                            3.1.2
# mizani                             0.13.1
# mkl                                2025.0.1
# ml-dtypes                          0.4.1
# mlxtend                            0.23.4
# more-itertools                     10.6.0
# moviepy                            1.0.3
# mpmath                             1.3.0
# msgpack                            1.1.0
# multidict                          6.1.0
# multipledispatch                   1.0.0
# multitasking                       0.0.11
# murmurhash                         1.0.12
# music21                            9.3.0
# namex                              0.0.8
# narwhals                           1.27.1
# natsort                            8.4.0
# nbclassic                          1.2.0
# nbclient                           0.10.2
# nbconvert                          7.16.6
# nbformat                           5.10.4
# ndindex                            1.9.2
# nest-asyncio                       1.6.0
# networkx                           3.4.2
# nibabel                            5.3.2
# nltk                               3.9.1
# notebook                           6.5.5
# notebook_shim                      0.2.4
# numba                              0.61.0
# numba-cuda                         0.0.17.1
# numexpr                            2.10.2
# numpy                              1.26.4
# nvidia-cublas-cu12                 12.5.3.2
# nvidia-cuda-cupti-cu12             12.5.82
# nvidia-cuda-nvcc-cu12              12.5.82
# nvidia-cuda-nvrtc-cu12             12.5.82
# nvidia-cuda-runtime-cu12           12.5.82
# nvidia-cudnn-cu12                  9.3.0.75
# nvidia-cufft-cu12                  11.2.3.61
# nvidia-curand-cu12                 10.3.6.82
# nvidia-cusolver-cu12               11.6.3.83
# nvidia-cusparse-cu12               12.5.1.3
# nvidia-nccl-cu12                   2.21.5
# nvidia-nvcomp-cu12                 4.1.0.6
# nvidia-nvjitlink-cu12              12.5.82
# nvidia-nvtx-cu12                   12.4.127
# nvtx                               0.2.10
# nx-cugraph-cu12                    24.12.0
# oauth2client                       4.1.3
# oauthlib                           3.2.2
# openai                             1.61.1
# opencv-contrib-python              4.11.0.86
# opencv-python                      4.11.0.86
# opencv-python-headless             4.11.0.86
# openpyxl                           3.1.5
# opentelemetry-api                  1.16.0
# opentelemetry-sdk                  1.16.0
# opentelemetry-semantic-conventions 0.37b0
# opt_einsum                         3.4.0
# optax                              0.2.4
# optree                             0.14.0
# orbax-checkpoint                   0.6.4
# orjson                             3.10.15
# osqp                               0.6.7.post3
# packaging                          24.2
# pandas                             2.2.2
# pandas-datareader                  0.10.0
# pandas-gbq                         0.27.0
# pandas-stubs                       2.2.2.240909
# pandocfilters                      1.5.1
# panel                              1.6.1
# param                              2.2.0
# parso                              0.8.4
# parsy                              2.1
# partd                              1.4.2
# pathlib                            1.0.1
# patsy                              1.0.1
# peewee                             3.17.9
# peft                               0.14.0
# pexpect                            4.9.0
# pickleshare                        0.7.5
# pillow                             11.1.0
# pip                                24.1.2
# platformdirs                       4.3.6
# plotly                             5.24.1
# plotnine                           0.14.5
# pluggy                             1.5.0
# ply                                3.11
# polars                             1.9.0
# pooch                              1.8.2
# portpicker                         1.5.2
# preshed                            3.0.9
# prettytable                        3.14.0
# proglog                            0.1.10
# progressbar2                       4.5.0
# prometheus_client                  0.21.1
# promise                            2.3
# prompt_toolkit                     3.0.50
# propcache                          0.2.1
# prophet                            1.1.6
# proto-plus                         1.26.0
# protobuf                           4.25.6
# psutil                             5.9.5
# psycopg2                           2.9.10
# ptyprocess                         0.7.0
# py-cpuinfo                         9.0.0
# py4j                               0.10.9.7
# pyarrow                            17.0.0
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.1
# pycocotools                        2.0.8
# pycparser                          2.22
# pydantic                           2.10.6
# pydantic_core                      2.27.2
# pydata-google-auth                 1.9.1
# pydot                              3.0.4
# pydotplus                          2.0.2
# PyDrive                            1.3.1
# PyDrive2                           1.21.3
# pyerfa                             2.0.1.5
# pygame                             2.6.1
# pygit2                             1.17.0
# Pygments                           2.18.0
# PyGObject                          3.42.1
# PyJWT                              2.10.1
# pylibcudf-cu12                     24.12.0
# pylibcugraph-cu12                  24.12.0
# pylibraft-cu12                     24.12.0
# pymc                               5.20.1
# pymystem3                          0.2.0
# pynvjitlink-cu12                   0.5.0
# pyogrio                            0.10.0
# Pyomo                              6.8.2
# PyOpenGL                           3.1.9
# pyOpenSSL                          24.2.1
# pyparsing                          3.2.1
# pyperclip                          1.9.0
# pyproj                             3.7.1
# pyreadr                            0.5.2
# pyshp                              2.3.1
# PySocks                            1.7.1
# pyspark                            3.5.4
# pytensor                           2.27.1
# pytest                             8.3.4
# python-apt                         0.0.0
# python-box                         7.3.2
# python-dateutil                    2.8.2
# python-louvain                     0.16
# python-slugify                     8.0.4
# python-snappy                      0.7.3
# python-utils                       3.9.1
# pytz                               2025.1
# pyviz_comms                        3.0.4
# PyYAML                             6.0.2
# pyzmq                              24.0.1
# qdldl                              0.1.7.post5
# ratelim                            0.1.6
# referencing                        0.36.2
# regex                              2024.11.6
# requests                           2.32.3
# requests-oauthlib                  2.0.0
# requests-toolbelt                  1.0.0
# requirements-parser                0.9.0
# rich                               13.9.4
# rmm-cu12                           24.12.1
# rpds-py                            0.22.3
# rpy2                               3.4.2
# rsa                                4.9
# safetensors                        0.5.2
# scikit-image                       0.25.2
# scikit-learn                       1.6.1
# scipy                              1.13.1
# scooby                             0.10.0
# scs                                3.2.7.post2
# seaborn                            0.13.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.3
# sentence-transformers              3.4.1
# sentencepiece                      0.2.0
# sentry-sdk                         2.22.0
# setproctitle                       1.3.4
# setuptools                         75.1.0
# shap                               0.46.0
# shapely                            2.0.7
# shellingham                        1.5.4
# simple-parsing                     0.1.7
# simsimd                            6.2.1
# six                                1.17.0
# sklearn-compat                     0.1.3
# sklearn-pandas                     2.2.0
# slicer                             0.0.8
# smart-open                         7.1.0
# smmap                              5.0.2
# sniffio                            1.3.1
# snowballstemmer                    2.2.0
# soundfile                          0.13.1
# soupsieve                          2.6
# soxr                               0.5.0.post1
# spacy                              3.7.5
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# spanner-graph-notebook             1.1.1
# Sphinx                             8.1.3
# sphinxcontrib-applehelp            2.0.0
# sphinxcontrib-devhelp              2.0.0
# sphinxcontrib-htmlhelp             2.1.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               2.0.0
# sphinxcontrib-serializinghtml      2.0.0
# SQLAlchemy                         2.0.38
# sqlglot                            25.6.1
# sqlparse                           0.5.3
# srsly                              2.5.1
# stanio                             0.5.1
# statsmodels                        0.14.4
# stringzilla                        3.11.3
# sympy                              1.13.1
# tables                             3.10.2
# tabulate                           0.9.0
# tbb                                2022.0.0
# tcmlib                             1.2.0
# tenacity                           9.0.0
# tensorboard                        2.18.0
# tensorboard-data-server            0.7.2
# tensorflow                         2.18.0
# tensorflow-datasets                4.9.7
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.37.1
# tensorflow-metadata                1.16.1
# tensorflow-probability             0.25.0
# tensorflow-text                    2.18.1
# tensorstore                        0.1.71
# termcolor                          2.5.0
# terminado                          0.18.1
# text-unidecode                     1.3
# textblob                           0.19.0
# tf_keras                           2.18.0
# tf-slim                            1.1.0
# thinc                              8.2.5
# threadpoolctl                      3.5.0
# tifffile                           2025.2.18
# timm                               1.0.14
# tinycss2                           1.4.0
# tokenizers                         0.21.0
# toml                               0.10.2
# toolz                              0.12.1
# torch                              2.5.1+cu124
# torchaudio                         2.5.1+cu124
# torchsummary                       1.5.1
# torchvision                        0.20.1+cu124
# tornado                            6.4.2
# tqdm                               4.67.1
# traitlets                          5.7.1
# traittypes                         0.2.1
# transformers                       4.48.3
# treescope                          0.1.9
# triton                             3.1.0
# tweepy                             4.15.0
# typeguard                          4.4.2
# typer                              0.15.1
# types-pytz                         2025.1.0.20250204
# types-setuptools                   75.8.0.20250210
# typing_extensions                  4.12.2
# tzdata                             2025.1
# tzlocal                            5.3
# uc-micro-py                        1.0.3
# umf                                0.9.1
# uritemplate                        4.1.1
# urllib3                            2.3.0
# vega-datasets                      0.9.0
# wadllib                            1.3.6
# wandb                              0.19.6
# wasabi                             1.1.3
# wcwidth                            0.2.13
# weasel                             0.4.1
# webcolors                          24.11.1
# webencodings                       0.5.1
# websocket-client                   1.8.0
# websockets                         14.2
# Werkzeug                           3.1.3
# wheel                              0.45.1
# widgetsnbextension                 3.6.10
# wordcloud                          1.9.4
# wrapt                              1.17.2
# xarray                             2025.1.2
# xarray-einstats                    0.8.0
# xgboost                            2.1.4
# xlrd                               2.0.1
# xyzservices                        2025.1.0
# yarl                               1.18.3
# yellowbrick                        1.5
# yfinance                           0.2.54
# zipp                               3.21.0
# zstandard                          0.23.0
# Collecting pygbif
#   Downloading pygbif-0.6.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>2.7 in /usr/local/lib/python3.11/dist-packages (from pygbif) (2.32.3)
# Collecting requests-cache (from pygbif)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting geojson_rewind (from pygbif)
#   Downloading geojson_rewind-1.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting geomet (from pygbif)
#   Downloading geomet-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting appdirs>=1.4.3 (from pygbif)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pygbif) (3.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>2.7->pygbif) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>2.7->pygbif) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>2.7->pygbif) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>2.7->pygbif) (2025.1.31)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from geomet->pygbif) (8.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (2.8.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache->pygbif) (25.1.0)
# Collecting cattrs>=22.2 (from requests-cache->pygbif)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache->pygbif) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache->pygbif)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pygbif) (1.17.0)
# Downloading pygbif-0.6.5-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 5.0 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading geojson_rewind-1.1.0-py3-none-any.whl (5.2 kB)
# Downloading geomet-1.1.0-py3-none-any.whl (31 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.7 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.0 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: appdirs, url-normalize, geomet, geojson_rewind, cattrs, requests-cache, pygbif
# Successfully installed appdirs-1.4.4 cattrs-24.1.2 geojson_rewind-1.1.0 geomet-1.1.0 pygbif-0.6.5 requests-cache-1.2.1 url-normalize-1.4.3

# %%
from pygbif import species as species
from pygbif import occurrences as occ
from pygbif.occurrences.download import GbifDownload
import os
import glob
import datetime
from time import sleep
import zipfile
import math

# add your gbif.org username, password and contact email for download notices to Colab's 'Secrets'
# toggle notebook access on for all three
# %env GBIF_USER=userdata.get('GBIF_USER')
# %env GBIF_PWD = userdata.get('GBIF_PWD')
# %env GBIF_EMAIL = userdata.get('GBIF_EMAIL')

SLEEP_DURATION = 20


# download GBIF species obs since 1970 within GL bounding box as zip files via API


skip = [] #skip taxa you previously exported a csv for

# get GBIF taxon IDs based on scientific names
def getskey(z):
  return species.name_backbone(z)['usageKey']

for i, (k, v) in enumerate(my_vars.items()):
  if not k in skip:
    records = []
    print("downloading ", k)
    splist = v['sci_name'].sum() # make list of all species inc. alternate scientific names
    #splist = list(set(splist))
    spkeys = [ getskey(x) for x in splist ]
    spkeys = list(map(str, spkeys))

    # construct query
    gbif_query = GbifDownload(userdata.get('GBIF_USER'), userdata.get('GBIF_EMAIL'))
    gbif_query.add_predicate_dict({"type": "in", "key": "BASIS_OF_RECORD", "values": ['HUMAN_OBSERVATION', 'OBSERVATION', 'MACHINE_OBSERVATION', 'LIVING_SPECIMEN', 'MATERIAL_SAMPLE'], "matchCase": "false"})
    gbif_query.add_predicate_dict({"type": "equals", "key": 'HAS_COORDINATE', 'value': 'TRUE', "matchCase": "false"})
    gbif_query.add_predicate_dict({"type": "equals", "key": 'HAS_GEOSPATIAL_ISSUE', 'value': 'FALSE', "matchCase": "false"})
    gbif_query.add_predicate_dict({"type": "within", "geometry": "POLYGON((-100.551 36.917,-71.79 36.917,-71.79 49.612,-100.551 49.612,-100.551 36.917))"})
    gbif_query.add_predicate_dict({"type": "greaterThanOrEquals", "key": 'YEAR', 'value': '1970', "matchCase": "false"})
    gbif_query.add_predicate_dict({"type": "in", "key": 'TAXON_KEY', 'values': spkeys, "matchCase": "false"})
    # submit download query
    xx = gbif_query.post_download(userdata.get('GBIF_USER'), userdata.get('GBIF_PWD'))
    # wait for download to be ready
    while True:
      print(f"waiting to get download {xx}...")
      status = occ.download_meta(key = xx)['status']

      if status not in ['PREPARING', 'RUNNING']:  # = not ready yet
          if status == 'SUCCEEDED':
              print(f"Download is ready, getting it")
              output_path = k+"_gbif_obs"
              if os.path.exists(output_path): # get rid of any previous downloads for this run
                files = glob.glob(output_path+'/*.zip')
                for f in files:
                  os.remove(f)
              else:
                os.mkdir(output_path)

              occ.download_get(xx, output_path)
          else:
              print(f"Status is {status}, why?")
              print(occ.download_meta(key = xx))
          break

      sleep(SLEEP_DURATION)

    print("finished with ", k)
# Out:
# env: GBIF_USER=userdata.get('GBIF_USER')
# env: GBIF_PWD=userdata.get('GBIF_PWD')
# env: GBIF_EMAIL=userdata.get('GBIF_EMAIL')
# downloading  fish
# waiting to get download 0002141-250221090833381...
# waiting to get download 0002141-250221090833381...
# waiting to get download 0002141-250221090833381...
# waiting to get download 0002141-250221090833381...
# waiting to get download 0002141-250221090833381...
# waiting to get download 0002141-250221090833381...
# Download is ready, getting it
# finished with  fish
# downloading  plant
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# waiting to get download 0002143-250221090833381...
# Download is ready, getting it
# finished with  plant
# downloading  invert
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# waiting to get download 0002144-250221090833381...
# Download is ready, getting it
# finished with  invert

# %%
gbif_obs = {}
gbif_observers = {}
# read the GBIF data back in and QA/QC it
for k in my_vars:
  # read zip file into dataframe
  output_path = k+"_gbif_obs"
  files = os.listdir(output_path)
  file_path = os.path.join(output_path, files[0])
  print(file_path)
  base_name, extension = os.path.splitext(files[0])
  zf = zipfile.ZipFile(file_path)
  df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
  # drop absences
  df = df.loc[df['occurrenceStatus'] == "PRESENT"]


  print(len(df.index), k, " records")
  gbif_observers[k] = df['recordedBy'].unique()

  df = df[['gbifID', 'species', 'eventDate', 'decimalLatitude', 'decimalLongitude']]
  df.rename(columns={'gbifID':'uid', "species":"sci_name", "eventDate":"obs_date", "decimalLatitude":"lat_dec", "decimalLongitude":"lon_dec"}, inplace=True)
  df["source"] = "GBIF"
  df['obs_date'] = df['obs_date'].str.slice(0, 10)
  df['obs_date'] = pd.to_datetime(df['obs_date'], format='mixed')
  # Drop rows with invalid dates
  df = df.dropna(subset='obs_date')
  df.reset_index(drop=True,inplace=True)
  # export to csv before continuing because this cell will take forever
  df.to_csv(output_path + '/'+ k +'_obs_gbifraw_' + datetime.date.today().strftime('%Y%m%d') + '.csv', index=False)
  # add to dict
  gbif_obs[k] = df
# Out:
# fish_gbif_obs/0002141-250221090833381.zip
# <ipython-input-5-985701b4f982>:12: DtypeWarning: Columns (17,29,36,37,38,39,40,41,43,44,46,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# 49894 fish  records
# plant_gbif_obs/0002143-250221090833381.zip
# <ipython-input-5-985701b4f982>:12: DtypeWarning: Columns (39,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# 17375 plant  records
# invert_gbif_obs/0002144-250221090833381.zip
# 8797 invert  records

# %%
# download potential pseudoabsences

for i, (k, v) in enumerate(my_vars.items()):
  if not k in skip:

    # get progress from previous runs
    if 'done' in locals():
      del done
    try:
      done = pabs[k]['identifiedBy'].iloc[-1]
    except:
      print('starting')

    records = []
    print("downloading ", k)
    # clean nans
    observers = gbif_observers[k]
    observers = [x for x in observers if x == x]
    observers.sort(key=str.lower)


    # too many observers, break into chunks
    start = 0
    end = len(observers)
    step = 50
    steps = math.ceil(end/step)
    for x in range(start, end, step):
      observers_chunk = observers[x:x+step]
      # skip already processed
      if 'done' in locals():
        if done > observers_chunk[0]:
          continue
      print(f'chunk {x}/{steps}: ', observers_chunk[0])
      # construct query
      gbif_query = GbifDownload(userdata.get('GBIF_USER'), userdata.get('GBIF_EMAIL'))
      gbif_query.add_predicate_dict({"type": "equals", "key": 'HAS_COORDINATE', 'value': 'TRUE', "matchCase": "false"})
      gbif_query.add_predicate_dict({"type": "equals", "key": 'HAS_GEOSPATIAL_ISSUE', 'value': 'FALSE', "matchCase": "false"})
      gbif_query.add_predicate_dict({"type": "within", "geometry": "POLYGON((-100.551 36.917,-71.79 36.917,-71.79 49.612,-100.551 49.612,-100.551 36.917))"})
      gbif_query.add_predicate_dict({"type": "greaterThanOrEquals", "key": 'YEAR', 'value': '1970', "matchCase": "false"})
      gbif_query.add_predicate_dict({"type": "in", "key": 'RECORDED_BY', 'values': observers_chunk, "matchCase": "false"})
      # limit results to more or less this type of organism
      if k == 'fish':
        gbif_query.add_predicate_dict({"type": "equals", "key": 'TAXON_KEY', 'value': 44, "matchCase": "false"})
      if k == 'plant':
        gbif_query.add_predicate_dict({"type": "equals", "key": 'TAXON_KEY', 'value': 6, "matchCase": "false"})
      if k == 'invert':
        gbif_query.add_predicate_dict({"type": "equals", "key": 'TAXON_KEY', 'value': 1, "matchCase": "false"})
        gbif_query.add_predicate_dict({"type": "not", "predicate": {"type": "equals", "key": 'TAXON_KEY', 'value': 44}})


      # submit download query
      xx = gbif_query.post_download(userdata.get('GBIF_USER'), userdata.get('GBIF_PWD'))
      # wait for download to be ready
      while True:
        print(f"waiting to get download {xx}...")
        status = occ.download_meta(key = xx)['status']

        if status not in ['PREPARING', 'RUNNING']:  # = not ready yet
            if status == 'SUCCEEDED':
                print(f"Download is ready, getting it")
                output_path = k+"_gbif_observer_potential_pseudoabs"
                if not os.path.exists(output_path): # get rid of any previous downloads for this run
                  os.mkdir(output_path)

                occ.download_get(xx, output_path)
            else:
                print(f"Status is {status}, why?")
                print(occ.download_meta(key = xx))
            break

        sleep(SLEEP_DURATION)

    print("finished with ", k)
# Out:
# starting
# downloading  fish
# chunk 0/23:  A Browning
# waiting to get download 0002200-250221090833381...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-b40fc940894f> in <cell line: 0>()
#      69             break
#      70
# ---> 71         sleep(SLEEP_DURATION)
#      72
#      73     print("finished with ", k)
#
# KeyboardInterrupt:

# %%
# process potential pseudoabsences
import zipfile

pabs = {}
for k in my_vars:
  # read zip file into dataframe
  output_path = k+"_gbif_observer_potential_pseudoabs"
  files = os.listdir(output_path)
  df_master = pd.DataFrame()
  flag = False

  for filename in files:


    file_path = os.path.join(output_path, filename)
    base_name, extension = os.path.splitext(filename)
    zf = zipfile.ZipFile(file_path)
    df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')

    if not flag:
        df_master = df
        flag = True
    else:
        df_master = pd.concat([df_master, df])

  pabs[k] = df_master

  # drop obs of target species




from pygbif import species as species
from pygbif import occurrences as occ
from pygbif.occurrences.download import GbifDownload

# add your gbif.org username, password and contact email for download notices to Colab's 'Secrets'
# toggle notebook access on for all three
# %env GBIF_USER=userdata.get('GBIF_USER')
# %env GBIF_PWD = userdata.get('GBIF_PWD')
# %env GBIF_EMAIL = userdata.get('GBIF_EMAIL')


# drop obs of target species
def getskey(z):
  return species.name_backbone(z)['usageKey']

for i, (k, v) in enumerate(my_vars.items()):
  splist = v['sci_name'].sum() # make list of all species inc. alternate scientific names
  #splist = list(set(splist))
  spkeys = [ getskey(x) for x in splist ]
  spkeys = list(map(str, spkeys))

  pabs[k] = pabs[k].loc[~pabs[k]['taxonKey'].isin(spkeys)]
  pabs[k] = pabs[k].loc[~pabs[k]['speciesKey'].isin(spkeys)]


  pabs[k].reset_index(drop=True,inplace=True)
# Out:
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (2,5,10,16,29,40,41,43,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (10,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (10,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (10,14,16,29,43,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# <ipython-input-32-9637b3a7e49b>:18: DtypeWarning: Columns (14,16,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(base_name+'.csv'), sep='\t')
# env: GBIF_USER=userdata.get('GBIF_USER')
# env: GBIF_PWD=userdata.get('GBIF_PWD')
# env: GBIF_EMAIL=userdata.get('GBIF_EMAIL')

# %%
# intersect with lakes
import geopandas as gpd
# lake polygone
lakes = gpd.read_file("/content/drive/My Drive/iedrr/NHDWaterbody_V2_LakePondReservoir_GLStates.json")
utm = lakes.estimate_utm_crs()
lakes = lakes.to_crs(utm)

for i, (k, v) in enumerate(my_vars.items()):
  print(k)
  if type(pabs[k]) == list:
    continue
  else:
    pabs_gdf = gpd.GeoDataFrame(pabs[k], geometry=gpd.points_from_xy(pabs[k]['decimalLongitude'], pabs[k]['decimalLatitude']), crs="EPSG:4326")
    pabs_gdf = pabs_gdf.to_crs(utm)
    print(len(pabs[k]))

    buffer_distance = 500  # meters

    # Create a buffer around each point

    joined_lakes = gpd.sjoin(lakes, pabs_gdf, predicate='dwithin', distance=buffer_distance)
    joined_lakes.rename(columns={"eventDate":"obs_date"}, inplace=True)
    joined_lakes['obs_date'] = joined_lakes['obs_date'].str.slice(0, 10)
    joined_lakes['obs_date'] = pd.to_datetime(joined_lakes['obs_date'], format='mixed')
    # Drop rows with invalid dates
    joined_lakes = joined_lakes.dropna(subset='obs_date')
    joined_lakes.reset_index(drop=True,inplace=True)

    pabs[k] = joined_lakes[['Permanent_', 'obs_date']]
# Out:
# fish
# 1412749
# plant
# 689565
# invert
# 2232407

# %% [markdown]
# # GLANSIS

# %%
import requests

# get GLANSIS's zipped csv of all data
url = "https://nas.er.usgs.gov/ipt/archive.do?r=nas_glansis"
filename = "GLANSIS_{}.zip".format(today)  # Choose a name for the downloaded file

response = requests.get(url)

if response.status_code == 200:
  with open(filename, "wb") as f:
    f.write(response.content)
  print("Zip file downloaded successfully.")
else:
  print("Failed to download the zip file.")
  # if dl fails, use most recent?
  #from pathlib import Path
  #DIR = Path("drive/My Drive/iedrr")
  #PATTERN = r'GLANSIS_*.zip'
  #latest_file = max(DIR.glob(PATTERN), key=lambda f: f.stat().st_ctime)

# open the zipped file
zf = zipfile.ZipFile(filename)
df = pd.read_csv(zf.open('occurrence.txt'), sep='\t')

df['eventDate'] = pd.to_datetime(df['eventDate'], format="%Y-%m-%d", errors='coerce')
# Drop rows with invalid dates
df = df.dropna(subset='eventDate')

#QAQC
df = df.loc[(df['decimalLatitude'] >= 36.917) & (df['decimalLatitude'] <= 49.612) & (df['decimalLongitude'] >= -100.551) & (df['decimalLongitude'] <= -71.79)] # bounding box
df = df.loc[df['eventDate']>datetime.datetime(1970,1,1)] # drop old data
df = df.loc[df['georeferenceRemarks'] != "Centroid"] # drop obs with poor coordinates
df.reset_index(drop=True,inplace=True)

glansis_obs = {}


for i, (k, v) in enumerate(my_vars.items()):
  splist = v['sci_name'].sum() # make list of all species inc. alternate scientific names
  hightax = []
  for item in splist:
    if len(item.split()) == 1:
      hightax.append(item)

  # drop nontarget species
  ndf = df[(df["scientificName"].isin(splist)) | (df["genus"].isin(hightax))]
  ndf.reset_index(drop=True)

  ndf = ndf[['id', 'scientificName', 'eventDate', 'decimalLatitude', 'decimalLongitude']]
  ndf.rename(columns={'id':'uid', "scientificName":"sci_name", "eventDate":"obs_date", "decimalLatitude":"lat_dec", "decimalLongitude":"lon_dec"}, inplace=True)
  ndf["source"] = "GLANSIS"
  glansis_obs[k] = ndf
# Out:
# Zip file downloaded successfully.

# %% [markdown]
# # MISIN

# %%
# !pip install esri2gpd
import esri2gpd

# %%
# MISIN observations layer updated daily
url = "https://services.arcgis.com/uHAHKfH1Z5ye1Oe0/arcgis/rest/services/misin_database_obs/FeatureServer/0"

misin_obs = {}
misin_reporters = {}

# convert esri date to datetime
def convert_esri_date(row):
    """Converts an esriFieldTypeDate value to a Python datetime object."""
    return datetime.datetime.fromtimestamp(row["DAY"] / 1000)  # Divide by 1000 to get seconds

for i, (k, v) in enumerate(my_vars.items()):
  print(k)
  # separate list of genera
  splist = v['sci_name'].sum() # make list of all species inc. alternate scientific names

  # separate out genera with no species epithet
  hightax = []
  for item in splist:
    if len(item.split()) == 1:
      hightax.append(item)
  if "Elodea densa" in splist:
    splist.append("Egeria densa") # MISIN is using Egeria densa instead of Elodea densa
  genus = [x.split()[0] for x in splist]

  gdf = esri2gpd.get(url, fields=['RECORDID', 'OBSERVER', 'DAY', 'LATITUDE', 'LONGITUDE', 'GENUS', 'SPECIES', 'VERIFIED'], where=f"GENUS IN {tuple(genus)}")
  gdf.dropna(subset=['DAY'], inplace=True)
  gdf["DAY"] = gdf.apply(convert_esri_date, axis=1)
  #QAQC
  gdf = gdf[gdf["VERIFIED"] == 2]  # for field VERIFIED, 2 = 'Trusted Source', only keep these
  gdf = gdf.loc[(gdf['LATITUDE'] >= 36.917) & (gdf['LATITUDE'] <= 49.612) & (gdf['LONGITUDE'] >= -100.551) & (gdf['LONGITUDE'] <= -71.79)] # bounding box
  gdf = gdf.loc[gdf['DAY']>datetime.datetime(1970,1,1)] # drop old data
  # drop nontarget species
  gdf["sci_name"] = gdf["GENUS"] + " " + gdf["SPECIES"]
  gdf_targets = gdf[(gdf["sci_name"].isin(splist)) | (gdf["GENUS"].isin(hightax))]
  gdf_targets.reset_index(drop=True,inplace=True)
  # get potential pseudoabsences
  misin_observers = gdf_targets['OBSERVER'].unique()
  print(len(misin_observers), 'observers')
  if len(misin_observers) > 30:
    obs_chunks = []
    start = 0
    end = len(misin_observers)
    step = 30
    for i in range(start, end, step):
      x = i
      observers_chunk = misin_observers[x:x+step]
      if len(observers_chunk) > 1:
        whereclause = f"OBSERVER IN {tuple(observers_chunk)}"
      else:
        whereclause = f"OBSERVER IN ('"+observers_chunk+"')"
      misin_pseudoabs = esri2gpd.get(url, fields=['RECORDID', 'OBSERVER', 'DAY', 'LATITUDE', 'LONGITUDE', 'GENUS', 'SPECIES', 'VERIFIED'], where=whereclause)
      misin_pseudoabs["sci_name"] = misin_pseudoabs["GENUS"] + " " + misin_pseudoabs["SPECIES"]
      misin_pseudoabs.dropna(subset=['DAY'], inplace=True)
      misin_pseudoabs["DAY"] = misin_pseudoabs.apply(convert_esri_date, axis=1)
      misin_pseudoabs = misin_pseudoabs.loc[(misin_pseudoabs['LATITUDE'] >= 36.917) & (misin_pseudoabs['LATITUDE'] <= 49.612) & (misin_pseudoabs['LONGITUDE'] >= -100.551) & (misin_pseudoabs['LONGITUDE'] <= -71.79)] # bounding box
      misin_pseudoabs = misin_pseudoabs.loc[misin_pseudoabs['DAY']>datetime.datetime(1970,1,1)] # drop old data
      misin_pseudoabs = pd.merge(misin_pseudoabs,gdf_targets, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
      obs_chunks.append(misin_pseudoabs)
    misin_pseudoabs = pd.concat(obs_chunks)
  else:
    misin_pseudoabs = esri2gpd.get(url, fields=['RECORDID', 'OBSERVER', 'DAY', 'LATITUDE', 'LONGITUDE', 'GENUS', 'SPECIES', 'VERIFIED'], where=f"OBSERVER IN {tuple(misin_observers)}")
    misin_pseudoabs.dropna(subset=['DAY'], inplace=True)
    misin_pseudoabs["DAY"] = misin_pseudoabs.apply(convert_esri_date, axis=1)
    misin_pseudoabs = misin_pseudoabs.loc[(misin_pseudoabs['LATITUDE'] >= 36.917) & (misin_pseudoabs['LATITUDE'] <= 49.612) & (misin_pseudoabs['LONGITUDE'] >= -100.551) & (misin_pseudoabs['LONGITUDE'] <= -71.79)] # bounding box
    misin_pseudoabs = misin_pseudoabs.loc[misin_pseudoabs['DAY']>datetime.datetime(1970,1,1)] # drop old data
    misin_pseudoabs = pd.merge(misin_pseudoabs,gdf_targets, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)

  gdf_targets.drop(['geometry', 'OBSERVER', 'GENUS', 'SPECIES', 'VERIFIED'], axis=1, inplace=True)
  gdf_targets.rename(columns={'RECORDID':'uid', "sci_name":"sci_name", "DAY":"obs_date", "LATITUDE":"lat_dec", "LONGITUDE":"lon_dec"}, inplace=True)
  gdf_targets["source"] = "MISIN"
  gdf_targets['uid'] = gdf_targets['uid'].astype(str)

  misin_pseudoabs.drop(['geometry', 'OBSERVER', 'GENUS', 'SPECIES', 'VERIFIED'], axis=1, inplace=True)
  misin_pseudoabs.rename(columns={'RECORDID':'uid', "sci_name":"sci_name", "DAY":"obs_date", "LATITUDE":"lat_dec", "LONGITUDE":"lon_dec"}, inplace=True)
  misin_pseudoabs['uid'] = misin_pseudoabs['uid'].astype(str)

  misin_obs[k] = gdf_targets
  misin_reporters[k] = misin_pseudoabs
# Out:
# 27 observers
# /usr/local/lib/python3.11/dist-packages/esri2gpd/core.py:91: UserWarning: Long download time — total download will require 148 separate requests
#   warnings.warn(
# <ipython-input-41-8f9834c5b833>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_targets.drop(['geometry', 'OBSERVER', 'GENUS', 'SPECIES', 'VERIFIED'], axis=1, inplace=True)
# <ipython-input-41-8f9834c5b833>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_targets.rename(columns={'RECORDID':'uid', "sci_name":"sci_name", "DAY":"obs_date", "LATITUDE":"lat_dec", "LONGITUDE":"lon_dec"}, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# 122 observers
# ['Phyllis Higman' 'Matt Ankney' 'Jo Latimore' 'Rosanne Rule'
#  'Tricia Brockman' 'Bulk Upload' 'Tom Alwin' 'Lindsay Peterson'
#  'Kirsten Johnson' 'Jennifer Johnson' 'Dan Keane' 'Kile Kucher'
#  'Drew Rayner' 'Alicia Ihnken' 'Nick Cassel' 'Greg Norwood' 'Jake Bonello'
#  'Ryan Wheeler' 'Stephen Hamilton' 'Aubri Spenski' 'Dani Mcgarry'
#  'Heather Dame' 'Syndell Parks' 'Andrew Tucker' 'Ben Luukkonen'
#  'Fallon Januska' 'Douglas Campbell' 'Doug Putt' 'Kevin Nietering'
#  'Kip Cronk']
# /usr/local/lib/python3.11/dist-packages/esri2gpd/core.py:91: UserWarning: Long download time — total download will require 157 separate requests
#   warnings.warn(
# ['Kellie Henige' 'Blake Mallory' 'Lee Schoen' 'William Keiper'
#  'Emily Schaefer' 'Shelby Bauer' 'Jessica Taylor' 'Ryan Crouch'
#  'Hannah Hudson' 'Drew Monks' 'Jason Combs' 'Brendan Carson' 'John Frye'
#  'Sarah Green' 'Audrey Menninga' 'Rachel Hackett' 'Blake Cahill'
#  'Leslie Clark' 'Daisy Orellana' 'Katie Grzesiak' 'Kim Steinberger'
#  'Michael Schindler' 'Joshua Cohen' 'McKenzi Bergmoser' 'Delaini Disher'
#  'Cleyo Harris' 'Hailey Reimann' 'Emily Messick'
#  'EGLE Water Resources Division' 'Michelle Vander Haar']
# /usr/local/lib/python3.11/dist-packages/esri2gpd/core.py:91: UserWarning: Long download time — total download will require 14 separate requests
#   warnings.warn(
# ['EGLE_WR' 'Dawn Hergott' 'Derek Shiels' 'McKenzi Walizcek'
#  'Emily Leffingwell' 'Jeff Williams' 'Robin Christensen' 'Rachel Leggett'
#  'Shikha Singh' 'Andrea Miller' 'Gedaliah Krasner' 'Samantha Nellis'
#  'Susan Fawcett' 'Carter Rogers' 'Alex Wieten' 'Amanda Klain '
#  'Matthew Lindauer' 'Chris Engle' 'Mary Bohling' 'Alex Florian'
#  'Fields Ratliff' 'Dean Johnson' 'Elizabeth Haber' 'Doug McLaughlin'
#  'Michael Hindy' 'Logan Hawley' 'Natalie Bekins' 'Abbey Drouillard'
#  'Michael Kost' 'Yan Lu']
# /usr/local/lib/python3.11/dist-packages/esri2gpd/core.py:91: UserWarning: Long download time — total download will require 11 separate requests
#   warnings.warn(
# ['Hollie Coleman' 'Amber Hubbard' 'Abigale Bristol' 'Jessica Ableson'
#  'Skyler Principe' 'Gadi Krasner' 'Adam Pierson' 'Sabrina Butler'
#  'Sabrina Butler ' 'Jami Vanscoyoc' 'Cake Team Lead' 'Liana May'
#  'Nathan Veres' 'Quincy Thayer' 'Shailey Harrington ' 'Megan Schildberg'
#  'Stephanie Hoyle' 'Kirsten Lyons' 'Louis Jochems' 'Taaja Tucker-Silva'
#  'Taaja Tucker-Silva ' 'amanda ruffini' 'Erica Clites' 'Elise Desjarlais'
#  'Ethan Teranes' 'Patrick Canniff' 'Stephanie Day' 'Molly Wozniak'
#  'Zach Peklo' 'Jessica Davenport']
# ['John Wickersham' 'Nichole Wohlstein']
# <ipython-input-41-8f9834c5b833>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_targets.drop(['geometry', 'OBSERVER', 'GENUS', 'SPECIES', 'VERIFIED'], axis=1, inplace=True)
# <ipython-input-41-8f9834c5b833>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_targets.rename(columns={'RECORDID':'uid', "sci_name":"sci_name", "DAY":"obs_date", "LATITUDE":"lat_dec", "LONGITUDE":"lon_dec"}, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# 54 observers
# ['Kirsten Johnson' 'Jennifer Johnson' 'Laura Herman' 'Adam Kessel'
#  'Angie Stine' 'Jo Latimore' 'Elizabeth Gulotty' 'Matthew Claucherty'
#  'Sarah LeSage' 'Lindsay Peterson' 'Seth Herbst' 'William Keiper'
#  'Ryan Van Goethem' 'Josh Dumke' 'Joe Leonardi' 'Kate Nietling'
#  'Laura Quist' 'Tom Alwin' 'Aaron parker' 'Jane Perrino' 'Sarah Green'
#  'George Madison' 'jay glase' 'Bulk Upload' 'John Bauman' 'Delaini Disher'
#  'EGLE Water Resources Division' 'Katie Grzesiak' 'Brian Gunderman'
#  'Emily Messick']
# /usr/local/lib/python3.11/dist-packages/esri2gpd/core.py:91: UserWarning: Long download time — total download will require 145 separate requests
#   warnings.warn(
# ['Lucas Nathan' 'Andrea Miller' 'Matthew Lindauer' 'Fields Ratliff'
#  'Alex Florian' 'Cory Kovacs' 'Katie Hager' 'Jason Broekstra'
#  'Shelby Bauer' 'Jennifer Bailey' 'Eliza Lugten' 'Shikha Singh'
#  'Joel Born' 'Amu Swainston' 'Gary Michaud' 'Michelle VanDenBrand'
#  'Paul Wiemerslage' 'Carole Gabbard' 'Michael Ramsey' 'Kendra Preston'
#  'Robert Coleman' 'Nick Theisen' 'Michael Hillary' 'Nichole Wohlstein']
# <ipython-input-41-8f9834c5b833>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_targets.drop(['geometry', 'OBSERVER', 'GENUS', 'SPECIES', 'VERIFIED'], axis=1, inplace=True)
# <ipython-input-41-8f9834c5b833>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_targets.rename(columns={'RECORDID':'uid', "sci_name":"sci_name", "DAY":"obs_date", "LATITUDE":"lat_dec", "LONGITUDE":"lon_dec"}, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# intersect pseudoobs with lakes
import geopandas as gpd
# lake polygone
if lakes is None:
  lakes = gpd.read_file("/content/drive/My Drive/iedrr/NHDWaterbody_V2_LakePondReservoir_GLStates.json")
  print(lakes.crs)
  utm = lakes.estimate_utm_crs()
  lakes = lakes.to_crs(utm)
  print(lakes.crs)

misin_abs = {}

for i, (k, v) in enumerate(my_vars.items()):
  print(k)
  if type(misin_reporters[k]) == list:
    continue
  else:
    misin_gdf = gpd.GeoDataFrame(misin_reporters[k], geometry=gpd.points_from_xy(misin_reporters[k]['lon_dec'], misin_reporters[k]['lat_dec']), crs="EPSG:4326")
    misin_gdf = misin_gdf.to_crs(utm)
    print(misin_gdf.crs)
    print(len(misin_reporters[k]))

    buffer_distance = 500  # meters

    # Create a buffer around each point

    joined_lakes = gpd.sjoin(lakes, misin_gdf, predicate='dwithin', distance=buffer_distance)

    joined_lakes = joined_lakes.dropna(subset='obs_date')
    joined_lakes.reset_index(drop=True,inplace=True)

    misin_abs[k] = joined_lakes[['Permanent_', 'obs_date']]
# Out:
# fish
# EPSG:32616
# 292027
# plant
# EPSG:32616
# 374003
# invert
# EPSG:32616
# 298914

# %% [markdown]
# # iMapInvasives

# %%
# !pip install esri2gpd
import esri2gpd
# in GL states, iMapInvasives obs are almost exclusively in PA and NY
# Out:
# Requirement already satisfied: esri2gpd in /usr/local/lib/python3.11/dist-packages (1.0.13)
# Requirement already satisfied: arcgis2geojson<3.0.0,>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from esri2gpd) (2.0.1)
# Requirement already satisfied: geopandas>=0.6 in /usr/local/lib/python3.11/dist-packages (from esri2gpd) (1.0.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from esri2gpd) (2.32.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.6->esri2gpd) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.6->esri2gpd) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.6->esri2gpd) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.6->esri2gpd) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.6->esri2gpd) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.6->esri2gpd) (2.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->esri2gpd) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->esri2gpd) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->esri2gpd) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->esri2gpd) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas>=0.6->esri2gpd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas>=0.6->esri2gpd) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas>=0.6->esri2gpd) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas>=0.6->esri2gpd) (1.17.0)
# 80 observers
# ['Robert Angyal - 2624' 'David Pawlowski - 3199' 'Stephen Walsh - 3173'
#  'Denise Clay - 2348' 'Amy Mahar - 3380' 'Stacy Furgal - 3099'
#  'Melissa Cohen - 2628' 'Brittney Rogers - 4361' 'Jeremy Dietrich - 3772'
#  'Doug Carlson - 2623' 'Scott Wells - 2656' 'Robert Schmidt - 3343'
#  'Emily Zollweg - 2659' 'Marcus Rosten - 4808' 'Brad Mudrzynski - 4546'
#  'SWFDB DEC Fisheries - 5612' 'John Farrell - 2660' 'Lucy Nuessle - 5893'
#  'Public Reports - 6034' 'USGS-NAS Database USGS-NAS Database - 6414'
#  'Kirkland Nagy - 7914' 'Alex Parry - 9741' 'John Cooper - 7454'
#  'Eric Chapman - 12691' 'Jennifer Dzimiela - 12864'
#  'Robert Morgan - 12423'
#  'Representative(s) from Gannon University - 12902'
#  'Representative(s) from PA Fish & Boat Commission - 12905'
#  'Mark Lethaby - 12659' 'Jim Grazio - 12566']
# ['Nate Irwin - 12682' 'Boris Kitevski - 13167' 'Rebecah Ford - 13589'
#  'Michael Hosack - 12669' 'Robert Wnuk - 12923' 'Jay Stauffer - 13678'
#  'USGS-NAS Database - 13574' 'Nick Macelko - 13476'
#  'Matthew Shank - 12575' 'Emily Sheridan - 3107' 'Bianca Gonzalez - 15848'
#  'Luke Gervase - 9596' 'Gary Smith - 12976' 'Jessica Newbern - 13419'
#  'Les Resseguie - 18751' 'Bob Reiter - 21681' 'Observer Unknown - 24082'
#  'Erin Vennie-Vollrath - 5136' 'Donald Kretser - 23899'
#  'Sean Hartzell - 21318' 'Michael Morgan - 3273'
#  'Kristopher Williams - 9274' 'Justin Noble - 24320'
#  'Josh Brandle - 24391' 'Angela Cook - 24411' 'Emily Emanuel - 24597'
#  'Kyle Zastrow - 25143' 'S T - 25165'
#  'Representative from Philadelphia Water Department - 26635'
#  'Francis Jones - 26643']
# ['Leslie Degen - 26644' 'Dan Powell - 26661'
#  'DEC DMR Marine Fisheries Database Generic Observer - 26424'
#  'Kyle  Glenn  - 29736' 'Veronica Mileski - 29534' 'Deon Dedeaux - 32470'
#  'Kari Minissale - 32341' 'Thad Yorks - 7950'
#  'Jennifer Dean - Admin - 2323' 'Jamie Jensen - 36708'
#  'Aaron Small - 37283' 'Travis Cornell - 37389' 'kevin Lynch - 37454'
#  'Alexa Howansky - 28804' 'Alexander Goldsmith - 37718'
#  'Sean Bird - 38288' 'Michael DiSarno - 38663'
#  'Representative(s) from Academy of Natural Sciences - 12910'
#  'Collector unknown - 12539' 'Chuck Brice - 26671']
# /usr/local/lib/python3.11/dist-packages/esri2gpd/core.py:91: UserWarning: Long download time — total download will require 61 separate requests
#   warnings.warn(
# 892 observers
# ['Robert L. Johnson - 2251' 'Stacy Furgal - 3099'
#  'Nancy Davis-Ricci - 2196' 'Janet Andersen - 2359'
#  'Meghan Johnstone - 3208' 'Mike McHale - 3108' 'Mike Goehle - 2611'
#  'Hilary Smith - 2303' 'Denise Clay - 2348' 'Greg Chapman - 3100'
#  'Emily Sheridan - 3107' 'Paul Marangelo - 15165' 'Jeff Sann - 3106'
#  'Scott Kishbaugh - 2262' "Heidi O'Riordan - 3281"
#  'Samantha Knowlden - 2433' 'Meg Wilkinson - 2084' 'Nancy Engel - 2511'
#  'Chuck Nichols - 3330' 'William Hoffman - 3168' 'Julie Nace - 3498'
#  'Kelly McDonald - 4071' 'Gail Meyer - 3182' 'Lawrence Eichler - 2255'
#  'Willard Harman - 3133' 'Heather Ruel - 2587' 'Alexis Alvey - 3283'
#  'Chris Lajewski - 2302' 'Alyssa Reid - 3025' 'Michael Goethle - 2121']
# ['Lindsay (Jody) Hoyt - 3750' 'Kevin Jennings - 3033'
#  'Marisa Kwoczka - 2529' 'Holly Menninger - 2247' 'Ariana Newell - 2377'
#  'Donna Vogler - 2395' 'Walt Nelson - 2283' 'David Newman - 4221'
#  'John Davis - 2452' 'Erik Posner - 3187' 'Kersten Laveroni - 3878'
#  'Meredith Taylor - 2488' 'Laurel Engelsson - 3867' 'Jerry Jenkins - 3881'
#  'Mathew Shawl - 3761' 'George Profous - 4194' 'Brad Wenskoski - 2732'
#  'Laurel Mann - 4342' 'Mark Rooks - 3983' 'Zachary Simek - 4559'
#  'Linda Ziemba - 4055' 'Deborah Hoppe - 4579' 'Logan West - 4562'
#  'Jennifer Schlick - 4564' 'Scott Ingmire - 4553' 'Frank Baehre - 3966'
#  'Kathy Schwager - 2086' "Robert O'Brien-OPRHP - 2280"
#  'Unknown Palmer - 2927' 'Steven Glenn - 3047']
# ['Tyler Smith - 2085' 'Unknown Pokorny - 2673' 'Susan Dobbertin - 2136'
#  'Elisha Gibson - 2140' 'Connie Tedesco - 2396' 'Unknown Buck - 2815'
#  'Laurie Freeman - 3367' 'Steve Glenn - 2160' 'Devin DuCeour - 2137'
#  'David Werier - 2080' 'Francine Stayter - 4306' 'Mary Binder - 4440'
#  'George Robinson - 4770' 'Steve Young - 2192' 'Paris Harper - 4872'
#  'Casey Holzworth - 2559' 'Bill McGhie - 4917' 'Cathy Matier - 4918'
#  'Bonnie Parton - 2368' 'Andrea Locke - 4707' 'Brad Mudrzynski - 4546'
#  'Elizabeth MacEwen - 5155' 'Sabrina Dreythaler - 5154'
#  'Michael Hough - 4532' 'Lorraine Skibo - 5195' 'Angela Driscoll - 4775'
#  'Kaleb Stores - 4792' 'Will Novitske - 12758' 'John DeHollander - 2714'
#  'Gabe Piazza - 5067']
# ['John Pokrzywka - 5050' 'Ian Schultz - 4426' 'Andrew Stadler - 5033'
#  'Dan_10 Rockefeller - 4974' 'Matt Frye - 3244'
#  'Erin Vennie-Vollrath - 5136' 'Guy Middleton - 2985'
#  'Kim Sherwood - 5363' 'Angie Martin - 4664' 'Kristina Younger - 5236'
#  'Victor Lamoureux - 5361' 'Jim Eckler - 3194' 'Bill Wolanske - 4964'
#  'Brenda Weaver - 4529' 'Mr. Slyer Classes Slyer Science Classes - 5447'
#  'Cara Lee - 2062' 'Kathryn Monacelli - 5479' 'Kristen Mooney - 5349'
#  'Hillary Siener - 5464' 'David Thomas-Train - 3719' 'Kali Bird - 3463'
#  'Daniel Kopec - 5554' 'Kristen Brewster - 5337' 'Eric Randall - 4039'
#  'Jessi Lyons - 2493' 'Spider Barbour - 2042' 'Shane Gebauer - 2054'
#  'Timothy Howard - 2056' 'Troy Weldy - 2079' 'Betty Ketcham - 2060']
# ['Adele Olivero - 2066' 'Greg J. Edinger - 2046' 'Andy Nelson - 2065'
#  'Elizabeth Spencer - 2071' 'Jennifer Garrett - 2053'
#  'Aissa Feldmann - 2050' 'Richard Ring - 2068' 'Kelly Perkins - 2199'
#  'Don Faber-Langendoen - 2049' 'Julie A. Lundgren - 2063'
#  'Kimberly Smith - 2200' 'Heidi Himes - 5643' 'David Hunt - 2057'
#  'Luke Wlasniewki - 5912' 'Leif Love - 5927' 'Caitlin Muller - 6021'
#  'Mat Levine - 3039' 'John Farrell - 2660' 'Benjamin Hansknecht - 6042'
#  'Katie McCann - 5928' 'Michael Parisio - 5922' 'Lucy Nuessle - 5893'
#  'Patty Wakefield-Brown - 5647' 'Holly Waterfield - 3135'
#  'Don Fisher - 5450' 'Emily Staychock - 5152' 'Michele Wunderlich - 2731'
#  'Marilyn Jordan - 2142' 'Nancy Stock - 6319' 'Joseph Clark - 6198']
# ['Hilary Mosher - 4778' 'Selma Rosenthal - 5807' 'William Wellman - 2977'
#  'Public Reports - 6034' 'Leigh Walrath - 3523' 'KG Karol - 6459'
#  'N Trigoboff - 6483' 'L Klotz - 6484' 'H Meyer - 6487'
#  'Robin Sleith - 6488' 'Chris Graham - 6412' 'Erik Kiviat - 2272'
#  'USGS-NAS Database USGS-NAS Database - 6414' 'Michael Sowinski - 6417'
#  'Michael Rider - 6320' 'Jacob Runner - 3666' 'David Kelley - 6031'
#  'George Stowers - 6871' 'Brian Schneider - 6936' 'April Brun - 6794'
#  'Fred Hensen - 2649' 'Daniel Langer - 6376' 'Jennifer Clark - 6824'
#  'Stephanie Larkin - 3032' 'Ashley Gingeleski - 6858'
#  'Laurel Gailor - 3111' 'Matt Brincka - 3837' 'Brendan Quirion - 2095'
#  'Colleen Lutz - 5591' 'Phillip Bonn - 6941']
# ['Renee Jensen - 7093' 'Roy Widrig - 4557' 'Sundas Rehman - 5633'
#  'Samantha Epstein - 5434' 'Ian Sansone - 6763' 'Tyler Christensen - 5724'
#  'Emily Dyett - 6829' 'Taylor Ouderkirk - 6783' 'Briggette Roos - 6813'
#  'Elyse Henshaw - 4966' 'Michelle Henry - 7147'
#  'Alexandra M. Corsini - 7181' 'Heather E. Maranville - 7193'
#  'Solitude Lake Management Data Set - 7546'
#  'DEC Lake Monitoring Data - 7053' 'Amy Mahar - 3380'
#  'Rebecca Pinder - 8009' 'Karen Terbush - 4952' 'Eric Jabot - 7119'
#  'Class Account Scotia-Glenville MS - 7693' 'Bobby Lemieux - 7916'
#  'Elisabeth Boemark - 7913' 'Ken Belfer - 7948' 'Ernest Coon - 7983'
#  'Derek Hilton - 8295' 'Sarah Crawford - 8296'
#  'Alexandra Henderson - 6874' 'Sue Gregoire - 6399'
#  'Patricia Shulenburg - 4450' 'Shaina Johnson - 6888']
# ['Emma Antolos - 4466' 'Alivia Sheffield - 8285' 'Kevin Sanders - 7017'
#  'Christopher Mitchell - 8227' 'Elizabeth Sammons - 6935'
#  'Tom Phillips - 8079' 'Morgan Motherwell - 8410' 'Joellen Lampman - 4879'
#  'Megan Phillips - 5025' 'Frederick Pintz - 8399'
#  'Elizabeth Blaschak - 7919' 'Amy McGinnis - 4640' 'John Thompson - 2074'
#  'Finger Lakes Macrophyte Survey Monitoring Program - 8575'
#  'Leah Gorman - 5069' 'Sean Benninger - 7918' 'Terry Smith - 8618'
#  'Paul Lord - 2274' 'Emily Carrollo - 8136' 'Pam Aprilliano - 8406'
#  'Steve Case - 3976' 'Sean Regalado - 5465' 'Bruce Friedmann - 3671'
#  'Philip Bossert - 6788' 'Heather Zimba - 6912' 'Sara Hill - 8713'
#  'Larry Litwin - 8740' 'Brittney Rogers - 4361' 'Eric Struening - 6086'
#  'Bryna Daykin - 8319']
# ['Alicia Wood - 8456' 'Nicholas Terracciano - 8773'
#  'Marilyn Fancher - 8565' 'Aaron Heminway - 6379' 'Spencer Barrett - 8003'
#  'Travis Ganter - 4354' 'Crystal Decker - 4355' 'Laura Cowger - 8438'
#  'John Lang - 6970' 'Matthew Paufve - 8301' 'John Butler - 9076'
#  'Ashley Leemans - 9533' 'Jason Hanselman - 9736' 'Luke Gervase - 9596'
#  'Tyler Levy - 9838' 'Tessa Artruc - 9743' 'Shaina Babcock - 9738'
#  'Tim Rice - 9742' 'Jennifer Dean - Admin - 2323'
#  'Elizabeth Truskowski - 9931' 'Christina Kolmann - 9950'
#  'Elizabeth-Ann Jamison - 9730' 'Kristopher Williams - 9274'
#  'Walter Dutcher - 4296' 'Jessica Ingham - 8025' 'Alex Parry - 9741'
#  'Jay White - 8969' 'Sarah Kirkpatrick - 9951' 'Brittany Lagaly - 9169'
#  'Zac Falconer - 9949']
# ['Lindsay Yoder - 9580' 'Alexandra Krohn - 9773'
#  'Kerry Crowningshield - 7783' 'Jessie Dixon - 8580'
#  'Michael Parker - 2725' 'Steven Pearson - 9597' 'Tyler Duby - 9772'
#  'Chelsea Cannon - 10099' 'Marcus Rosten - 4808' 'Sarah Ganter - 9760'
#  'Anne Rhoads - 9237' 'Jennifer Dunn - 3801' 'Scott Cornett - 2626'
#  'Rebecca Mann - 9560' 'Scott Proctor - 5875' 'Falon Neske - 9338'
#  'Lem Hegwood - 10310' 'Gwendolyn Temple - 6754' 'John Marino - 8933'
#  'Mary Beth Mylott - 10168' 'Craig Jackson - 8674' 'Larry Master - 2456'
#  'Lawrence Rossini - 5466' 'Anthony Dolce - 10521' 'Lynn Bogan - 3191'
#  'David Andrews - 9471' 'Jayla White - 10211' 'Kierstin Carlson - 12416'
#  'Sarah Ernst - 12448' 'James K. Bissell - 12435']
# ['William Harrison - 12451' 'Steven P. Grund - 12449'
#  'Brosi A. Bradley - 12440' 'M. Loree Speedy - 12445'
#  'Lindsey Miller - 12444' 'Sara V. Parker - 12447'
#  'Frederick H. Utech - 12430' 'M. Polechko - 12516'
#  'Sarah Whitney - 12557' 'Gretchen Schatschneider - 12561'
#  'Amy Jewitt - 12931' 'Tim Wood - 12614' 'Barbara Lathrop - 12559'
#  'Kevin Kelly - 12671' 'Steve Means - 12649' 'Sherry Leap - 12757'
#  'Glenn Sullivan - 12860' 'Peter Woods - 12738' 'Andrew Zadnik - 12771'
#  'Robert Harris - 12816'
#  'Representative(s) of Weed Warriors (Presque Isle) - 12911'
#  'Jean Gomory - 12933' 'Allison Sanderson - 12914'
#  'Krista Scheirer - 12869' 'Sara Stahlman - 12560'
#  'Brian Pilarcik - 12916' 'Fawn Kearns - 12921' 'Ron Keeney - 12918'
#  'Daniel Bickel - 13224' 'Jessie Kemper - 13057']
# ['Representative(s) from Princeton Hydro - 13098'
#  'Michael Hartshorne - 13082' 'Jim Grazio - 12566' 'Diana Restifo - 13110'
#  'William Kirkpatrick - 13171' 'Kevin Hess - 12721' 'Rachel Reese - 12872'
#  'Alan Everett - 12800'
#  'Representative(s) from Natureworks, Clear Water Associates, Inc. - 13179'
#  'Dean Jones - 1294' 'Robert Booth - 13258' 'Nick Decker - 13177'
#  'John Levitsky - 13009' 'Dwayne Hess - 13248' 'Jamie Knecht - 13288'
#  'Jodi Sulpizio - 13322' 'Kim Van Fleet - 13427' 'Mary Walsh - 12415'
#  'Nick Macelko - 13476' 'Meghan Rogalus - 12586'
#  'Jeanette Girosky - 12610' 'Becky Lynn Travis - 13601'
#  'Stacie Hall - 12947' 'Mark Warman - 13311' 'Trish Harrington - 13739'
#  'Autumn Thomas - 13387' 'Jessica McPherson - 12556'
#  'Collector unknown - 12539' 'USGS-NAS Database - 13574'
#  'Nick Trivelli - 13839']
# ['Jim Walter - 13825' 'Edward Phalen - 13886' 'Gregory Lech - 13213'
#  'Kent Taylor - 13795' 'Robert S. Whyte - 13887' 'William Gleason - 12450'
#  'J. W. Fetzner - 14039' 'Alejandro Reyes - 3777' 'John MarinoL2 - 10333'
#  'Kenneth Hawks - 4754' 'Bianca Gonzalez - 15848' 'Jeff O Handley - 4631'
#  'Trea Schumacher - 16017' 'Ralph Green - 15951' 'Jared Parsons - 16066'
#  'Jason Kappan - 15959' 'Robert Merritt - 15948' 'Krista Scheirer - 16315'
#  'Anna Kuhne - 9638' 'Katelin Quarles - 15913' 'Lauren Mercier - 10563'
#  'Paulina Murray - 7654' 'Frank Williams - 7000' 'Grace Bichler - 16064'
#  'Ashley Aupperle - 11178' 'Jeremiah Martin-Johnson - 16518'
#  'Thomas Simmons - 10259' 'Rebekah Pauley - 16188'
#  'Jessica Newbern - 13419' 'Teresa Pfeifer - 16693']
# ['Emily Harrower - 15924' 'Gerhard Schlingmann - 16706'
#  'Scott Kishbaugh - 16730' 'Cora Delucia - 16025' 'Mary Keefe - 15981'
#  'Jannell Nickols - 16112' 'Nicole White - 16784' 'Everett McNeill - 8690'
#  'Richard Hadcock - 16803' 'Keri VanCamp - 8076' 'David Kelley - 16107'
#  'Julia R Gerard - 9408' 'Felicia Lamphere - 13977'
#  'Margaret  Butler - 16923' 'Victoria Herkalo - 16766'
#  'Jeremy Miller - 16564' 'Nancy VanCott - 16968' 'William McAdoo - 16995'
#  'Josh Neff - 7926' 'Jessica Goretzke - 7895' 'Kristin Fitzgerald - 6258'
#  'Joseph  Perrelli - 16990' 'Ryan Elliott - 7478' 'Ally Jones - 17118'
#  'R H - 17142' 'Cindy Rider - 11396' 'Rick Gerardi - 17163'
#  'Observer Unknown - 269' 'Taylor West - 17159' 'Cara Sherman - 16717']
# ['Karen Terbush - 16816' 'Cathy Pedler - 5026' 'Stephanie June - 15949'
#  'Krystal Piucci - 17220' 'John Ozard - 17531' 'Laura Bailey - 6642'
#  'Kyle Thaine - 16074' 'Brian Henry - 17236' 'Matthew Kraft - 15548'
#  'Mark Whitmore - 2296' 'Thomas Wynne - 17834' 'Meg Janis - 2346'
#  'Nicole DeCarolis - 17925' 'Bill Jacobs - 2141' 'Ashley Young - 10353'
#  'daniel laury - 17850' 'Brian Siklinski - 5055' 'Irene Holak - 9966'
#  'Kristen Wilde - 6989' 'Lindsay Charlop - 17204'
#  'Zachariah Glaspy - 7824' 'Adam Lamancuso - 16218' 'Ellen Collins - 3616'
#  'Marcus Harazin - 5264' 'Lindsey Duval - 18717' 'Jared Bedient - 10081'
#  'Daina Krumins - 15753' 'Justin SEMKE - 19448' 'Michael Kastan - 19374'
#  'Melissa Foucreau - 19636']
# ['Christopher Mazzeo - 19637' 'Kayla Lenway - 19633' 'Devin Smith - 16817'
#  'Lauren Henderson - 19154' 'Steven Anthony - 19619'
#  'Daniel Sorensen - 13159' 'Nicole Campbell - 7176'
#  'Elizabeth Bradshaw - 19635' 'Alex Linerode - 19694'
#  'Amanda Helseth - 19221' 'Sierra Stickney - 19576'
#  'Ashley Morris - 19032' 'Ross McLennan - 16971' 'Sarah Coney - 8462'
#  'Alexander Krest - 19533' 'Sam Schultz - 9924' 'Emma Sarnacki - 20171'
#  'Jeremy Woolson - 18720' 'Kurt Jirka - 20239' 'Kurt Moser - 20241'
#  'David Nelson - 20266' "Mitchell O'Neill - 18716"
#  'Louisa Sorriento - 8728' 'Sara Stebbins - 19541' 'Ed Hawkey - 20216'
#  'Paula Walter - 20137' 'Thomas Starkey - 7344' 'Kelsea Rogers - 18606'
#  "CLAIRE O'NEILL - 18686" 'Joyce Tomaselli - 4537']
# ['Stephen Litwhiler - 3893' 'Thomas Smith - 20662'
#  'David R. Fowler - 13569' 'Monica Caves - 9473'
#  'Garrett Chisholm - 18757' 'Gavin Berdan - 20604' 'Alex Stalica - 20603'
#  'John Titus - 20761' 'Winston Gedicks - 9521' 'Danielle Dolan - 19681'
#  'Tessa Pemrick - 17669' 'Mark Teece - 20852' 'Michael Giambalvo - 19981'
#  'Mikael Ann Melfi - 19588' 'Kimberly Fortune - 20897'
#  'winnona brust - 20900' 'Sarra Learned - 20738' 'Eva Carman - 20869'
#  'Donald Kerr - 20916' 'Nelson Dumas - 7096' 'Jacob Cramer - 16387'
#  'Jill Bilodeau - 21221' 'Hannah Bequeath - 20892'
#  'Justin Searles - 19615' 'Nancy Clarke - 20988' 'Tarki Heath - 4556'
#  'Megan Pistolese - 4365' 'Nicole Carville - 21677'
#  'Leigh Walrath - 15829' 'Nick Smith - 21844']
# ['Laura Shappell - 6374' 'Sonia Sandoval - 7130' 'Janelle Jones - 7601'
#  'Alexis Bashta - 19846' 'Andrew Glaspell - 21859'
#  "Azure D'Angelo - 19847" 'Charles Reick - 21861'
#  'Courtney Renner - 21862' 'Hannah Foster - 21863'
#  'Jennifer Kelly - 21370' "Jennifer O'Shea - 9470" 'Kaitlin Fello - 21864'
#  'Kori Malsegna - 19845' 'Lindsay McMillan - 7505' 'Maria Vidal - 21865'
#  'Megan Harris - 19842' 'Megan Swing - 19657' 'Phil Simmons - 21866'
#  'Stuart Messur - 21867' 'Victoria Tidball - 21868' 'Rich Adams - 21881'
#  'Lynn Klotz - 8616' 'Jennifer Bailey - 15979' 'Dan Corbett - 21368'
#  'Michael Yost - 21373' 'William Ebert - 8624' 'Emelia Yost - 10079'
#  'Sam Shephard - 16160' 'Matthew Gallo - 21992'
#  'Jonathan Townsend - 16187']
# ['APIPP Data Recorder - 19322' 'Jeff Tome - 18721'
#  'iNaturalist User - 12134' 'Maxine Hill - 23026' 'Ava L - 18755'
#  'Alexis  Tate - 23282' 'Sean Hartzell - 21318' 'Thomas Firkins - 22872'
#  'Patrick Bly - 22875' 'Adirondack Research Generic Observer - 22879'
#  'Vara Connor - 22874' 'Mark Privee - 22873' 'Clara Lloyd - 19902'
#  'Brian Greene - 23174' 'Ty Sharrow - 20699' 'Connor Curley - 23616'
#  'Jennie Suchewski - 23619'
#  'NYNJTC Aquatic Invasives Strike Force - 23520'
#  'Madison Michetti - 23747' 'Christian Brashear - 17730'
#  'Mary Beth Kolozsvary - 3399' 'Intern Prism - 22552'
#  'Sheila Sicilia - 3979' 'Colleen Andrews - 23885'
#  'Kayanne Gsellmeier - 23933' 'Cindy Major - 16529' 'Sydney Aveson - 8676'
#  'Christina VanDusen - 19530' 'Shelby Crawford - 23772'
#  'Brian Daggs - 23757']
# ['Alexandra Mitchell - 19659' 'Will Parker - 23796'
#  'Generic Survey123 User - 20133' 'Ezra Schwartzberg - 3971'
#  'Trudy Rowe - 3665' 'Matthew Biondolillo - 19493'
#  'Madeline Maitino - 16092' 'Jacob Moore - 23244' 'Jessica Kester - 13632'
#  'Julie Romano - 24388' 'Buffer Steward  Chenango County SWCD - 24318'
#  'Historical DEC Generic Observer - 24174' 'Andrew Conboy - 20713'
#  'Nikki Nowak - 24236' 'Gregory Zuill - 23245' 'Steven Daniel - 18356'
#  'Deaglan McManus - 13740' 'Toni Peterson - 24115' 'Mark Gibson - 23844'
#  'Emily Thiel - 9561' 'Abby Lanterman - 20060' 'Mary Greagan - 9127'
#  'Cathy Marczyk - 24558' 'Jerry Chiocchio - 24589' 'Evan Bennett - 23448'
#  'Ross Abbett - 24456' 'Brad Cramer - 21979' 'Madeline Ebert - 19663'
#  'Chris Bryant - 23451' 'Elizabeth Snow - 24286']
# ['Paul Siskind - 8662' 'Jessica Hicks - 23748' 'STEPHEN Miller - 23860'
#  'Ann Rhoads - 13183' 'Emily Timkey - 19692' 'Dan Belliveau - 24452'
#  'Haley Gladitsch - 22236' 'Andrew Randazzo - 15728' 'Carole Henry - 9629'
#  'David Carr - 10459' 'SOLitude Lake Management Generic Observer - 24827'
#  'Marty Miesko - 25111' 'Mary Underhill - 2561' 'Liz McCheyne - 23131'
#  'Peter Lombardi - 25087' 'Rose Helmer - 24785' 'Barry Ceci - 25374'
#  'Hannah Coppola - 21052' 'Janice Reynen - 22687' 'Robert Smith - 16532'
#  'Kathleen McGrath - 9123' "Jim D'Angelo - 24117" 'Patricia Bedard - 8458'
#  'Catherine McGlynn - 2332' 'Sonya Bayba - 21634' 'Amy Funkhouser - 23100'
#  'Elaina McCartney - 23854' 'Nicole Smeenk - 16162'
#  'Matthew Dombrowski - 26651' 'Rocky Gleason - 22169']
# ['Michael Beahm - 26562' 'Abigail Bezrutczyk - 8887' 'Jesse Keltz - 26829'
#  'Alene Onion - 6925' 'Rebecca Gorney - 5556' 'Jeff Lojpersberger - 26830'
#  'Josh Young - 26421' 'Susan Lynch - 27561' 'Lura Johnson - 26420'
#  'Timothy Murphy - 26422' 'Erin Siebert - 22004' 'Emma Wilber - 21915'
#  'Chris Graham - 27820' 'Andrew Turner - 12602' 'Sydney VanWinkle - 10488'
#  'Jakob Scholeno - 23794' 'Dorothea Mildenberger - 23799'
#  'Molly Giles - 28729' 'Sierra Stickney - 28620' 'Justin Lamie - 23243'
#  'Caleb Lines - 28775' 'Strike Team Technician - 28619'
#  'Martha Suquet - 29100' 'skyler braeges - 24127' 'Ed Filip - 12789'
#  'Nicholas Klock - 23901' 'Joshua Neff - 23828'
#  'Caroline Franczak - 23792' 'Monica Groth - 23793' 'Connor  Vara - 29183']
# ['Kevin Musser - 29132' 'eric eagan - 29347' 'Scott Bush - 12645'
#  'Jay Chapman - 5839' 'Nicole Cassella - 29422' 'ACNC  Jamestown - 29001'
#  'Jade LaRock - 27551' 'Priscilla Titus - 4946' 'Michael Robinson - 27165'
#  'Karen Fusco - 29512' 'Richard Brown - 29553' 'Glenn Sullivan - 7944'
#  'Twan Leenders - 28937' 'Michael Robinson - 26637'
#  'Matthew Gorman - 28948' 'Kristen Shand - 24673'
#  'William Ellsworth - 4550' 'Mike Ackley - 29778' 'Sydney Tredo - 28932'
#  'Adellia Baker - 20258' 'Casen Weeden - 28599' 'Jon Titus - 4945'
#  'Eric Maringer - 29847' 'Judy Dobles - 24518' 'Forrest Gifford - 28776'
#  'Alexa Howansky - 28804' 'Maya Thompson - 28509' 'Daina Krumins - 20202'
#  'Diego Diaz - 28777' 'Lois Campbell - 30054']
# ['Jesse  Stevens - 20578' 'Ausable River Association  - 15912'
#  'Kristin Ching - 28773' 'Renee Wickman - 19513'
#  'Alyssa Schoenfeldt  - 29304' 'Michaela Otis - 30106'
#  'Timothy Bechard - 30100' 'Megan Kirby - 28868' 'Jerry Weber - 29910'
#  'Adam Hess - 29005' 'Elizabeth Kunze - 29059' 'Antoinette Miller - 29056'
#  'Steve Fulton - 24267' 'Dorene McCann - 29575'
#  'Abigail Van Slyke - 30169' 'Vincent Manuella - 20809'
#  'Sam Burrell - 5082' 'William Snyder - 10819' 'Anne Klingensmith - 30240'
#  'Kenneth Brownell - 28649' 'Joyce Brunet - 30090'
#  'Cortney VanCour - 30289' 'Devin DiGiacopo - 27768' 'Tobyn Olds - 28489'
#  'Joseph Opferman - 30467' 'Heather Platt - 29232' 'Dan Smith - 10812'
#  'Tyler Harrington - 25630' 'Michelle McGill - 28883'
#  'Julia Bugayov  - 22805']
# ['Joan Hodges - 28884' 'Brianna Saylor - 20485' 'Luke Thompson - 28714'
#  'Zach Nyhart - 28709' 'Nate Hartley - 18922' 'Leslie Surprenant - 2300'
#  'Hillary Kenyon - 22272' 'Aurora Kuczek - 23797' 'Evan Spencer - 28691'
#  'Meghan Bargabos - 28810' 'Kevin Dernier - 29227' 'Beth Fisher - 28708'
#  'Clarissa A Longoria - 28961' 'Masen Sharpe - 28674'
#  'Mia  Walton  - 29113' 'Dan Woltmann - 29085' 'Isaiah Johnson - 27795'
#  'Michele Curry - 31986' 'Beatrice Moss - 31899' 'Gary Robusto - 27391'
#  'Ning Zou - 32741' 'Catherine Farrell - 28548' 'Dana Holmlund - 32627'
#  'Justin  Zito - 32673' 'Representative from iNaturalist.org - 12903'
#  'Noah Yawn - 32977' 'Mitchell Meuser - 32979' 'Anna Trombetta - 32675'
#  'Rachel Rowlee - 32751' 'Leigh Walrath - 33209']
# ['Valerie Ellison - 32718' 'Michael Mamone - 33118'
#  'Jessica Pyrda - 33338' 'Nick Zamelis - 32752' 'Brea Arvidson - 19275'
#  'Mary Hawkins - 33513' 'Danielle Rhea - 17499' 'Robert Rahm - 30690'
#  'Alyvia Nazak - 33205' 'Amy Slentz - 31615' 'Meghan Sambrook - 33468'
#  'Rachel Taylor - 30957' 'Matthew Simonds - 33652' 'Melody Penny - 27939'
#  'Marshall Lefebvre - 7708' 'kimberly smith - 33834'
#  'Matthew Boylan - 31771' 'Penny Gould - 8392' 'Julianna Skill - 27708'
#  'USDA-FS Finger Lakes National Forest Generic Observer - 33406'
#  'Bonnie L. Isaac - 12427' 'Erin Norton - 26825'
#  'Chelsea Broughton - 31681' 'Alejandro Reyes - 31230'
#  'Warren County GIS and Lake Associations Generic Observer - 34025'
#  'Susan Rdzanek - 34206' 'Lillian Forward - 34231'
#  'Chris Halliday - 26579' 'Jcswcd Jcswcd - 31845' 'Keith McKeever - 34731']
# ['Grace Rau - 34806' 'Adam McIntyre - 32762' 'Wenchengyuan Hu - 33094'
#  'Amanda Cooper - 31394' 'Markus Shearer - 34670'
#  'Eileen Fitzgerald - 35466'
#  'Fort Drum Field Crew Generic Observer - 38772'
#  'Allied Biological Generic Observer - 36383' 'Angela Spagnoli - 36736'
#  'Morgan Hilliard - 32396' 'Justin Wolford - 21136' 'Tucker Wells - 32469'
#  'Gage Root - 32360' 'Tucker Jakobe - 32622' 'Julia  Luna  - 28958'
#  'Zoe Fox - 36645' 'Kelly Mcnamara  - 36648' 'Christina Arroyo - 36625'
#  'Corey Matthews - 37015' 'Jay Young - 29872' 'Buffer Steward - 37069'
#  'Megan Spring - 36886' 'Madelynn Ackley - 28712' 'James Wagner - 37345'
#  'Jimi Wiggins - 31956' 'Karen  Campbell - 24850' 'Chris Emerson - 36530'
#  'Alex McGraw - 37475' 'Brad Baldwin - 34693' 'Nino Polidori - 37422']
# ['Zoe Meyer - 36588' 'Judson Dasno - 28798' 'Robert Fournier - 29848'
#  'Adrian Cattell - 31072' 'Brian McAllister - 36837'
#  'Abigail Kaurin - 36575' 'Kristen Haynes - 26349' 'Scott Mulcahy - 37423'
#  'Anna Haws - 36281' 'Louis DECUNZO - 37351' 'Dylan Elman - 37623'
#  'Donna Coffey - 33176' 'Caitlin Canario - 23811' 'Benton McGowan - 32847'
#  'Camille Caceci - 19037' 'Carlo Owen Lorenzetti - 34078'
#  'Lukas Rood - 27569' 'Penny Adler-Colvin - 29417'
#  'Edward Woltmann - 37813' 'Mary Ann Benacci - 37851'
#  'Lara Hargrave - 37550' 'Christine  Venery  - 37848'
#  'Dominic Peters - 24584' 'Leonard Schantz - 10456' 'Brad Cramer - 21948'
#  'Nicholas Farese - 36229' 'Michael Fogarty - 38038'
#  'Abigail Paro - 36716' 'Jason Luce - 4677' 'Mike Voorhees - 21250']
# ['Colleen Keefer - 9498'
#  'United States Army Corps of Engineers (USACE)  Generic Observer - 38124'
#  'iNaturalist User [NY] - 20882' 'Tracey Toufali - 24902'
#  'Tristan Jaeger - 37117' 'Gage Altman-Lewis - 36991'
#  'Kassidy Robinson - 31388' 'Mark Kirwan - 32887' 'Jillian Harris - 7173'
#  'Tyler Harrington - 30638' 'Abigail Minnekine - 35101'
#  'Emily Rando - 36672' 'Jet Meyer - 32848' 'Noah Blocher - 36673'
#  'Sam Busco - 21139' 'Elisabeth Bata - 32878' 'steven altrieth - 32990'
#  'Yuriy Litvinenko - 15775' 'Hilary Cresko - 36086'
#  'Rebecca Ferry - 19499' 'Andriy Gura - 29505' 'Katrina Hanley - 33881'
#  'Douglas Knoph - 20109' 'Kaitlyn Cunningham - 24283' 'Taylor Dee - 29064'
#  'Edward Budai - 28819' 'Keith Kanoti - 31396' 'Heidi Krahling - 2478'
#  'Norma L. Kline - 12555' 'Charles W. Bier - 12441']
# ['Joe A. Isaac - 12432' 'Robert B. Coxe - 12446' 'Sue Thompson - 12426'
#  'Ted J. Grisez - 12534' 'Allison W. Cusick - 12436'
#  'R. C. Leberman - 12521' 'H. Kline - 12487' 'John R. Kunsman - 12443'
#  'Robert S. Mulvihill - 12452' 'J. M. Eggers - 12496'
#  'Jeffrey D. Wagner - 12442' 'Mark Stockley - 13035'
#  'Representative(s) from Department of Conservation and Natural Resources - 12953'
#  'Dan Farnham - 13184' 'Timothy Block - 12899'
#  'D. A. Hewitt and A. E. Schuyler - 13186' 'Timothy C. Plowman - 13379'
#  'Mark Simonis - 13383' 'W. J. Harrison - 14022' 'W. Novitske - 14151'
#  'L. Speedy - 14242' 'Cheryl Snyder - 12832']
# <ipython-input-59-9ad4f4ce9418>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rdf.rename(columns={'present_species_id':'uid', "scientific_name":"sci_name", "observation_date":"obs_date"}, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# <ipython-input-59-9ad4f4ce9418>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rdf.drop(['geometry', 'observer_name', 'jurisdiction', 'genus'], axis=1, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# 204 observers
# ['Meghan Brown - 3011' 'Dave Strayer - 3143' 'David Thompson - 13893'
#  'Alexander Karatayev - 3510' 'Mike McHale - 3108' 'Donna Vogler - 2395'
#  'Emily DeBolt - 17819' 'Amy Mahar - 3380' 'Mike Ellrott - 3236'
#  'Doc Bayne - 3861' 'Bruce Natale - 2751' 'Nancy Engel - 2511'
#  'Kristen Rohne - 2740' 'Jeff Corser - 2195' 'Meg Modley - 3258'
#  'Luke Myers - 3977' 'Bradley Bowers - 3127' 'Julie A. Lundgren - 2063'
#  'Derek Conant - 3670' 'unknown Austerman - 3518' 'Jesse Jaycox - 2552'
#  'Willard Harman - 3133' 'Russell Nemecek - 4088' 'Doug Carlson - 2623'
#  'Casey Holzworth - 2559' 'Cody Mendoza - 3396' 'Jordan Youngmann - 4446'
#  'Edward Levri - 12746' 'Robert Schmidt - 3343' 'Jeremy Dietrich - 3772']
# ['Bob Daniels - 3252' 'Diana Heitzman - 3512' 'Cameron Jenness - 4661'
#  'Francine Stayter - 4306' 'Damian Griffin - 3488'
#  'Michele Wunderlich - 2731' 'Elizabeth MacEwen - 5155'
#  'Fredric Dunlap - 4196' 'Samantha Olsen - 5309' 'Eric Holmlund - 2304'
#  'John Slyer - 5430' 'Tom Brooking - 6113'
#  'USGS-NAS Database USGS-NAS Database - 6414' 'April Brun - 6794'
#  'David Newman - 4221' 'Emily Dyett - 6829' 'Erin Vennie-Vollrath - 5136'
#  'Ashley Gingeleski - 6858' 'Heather E. Maranville - 7193'
#  'Jennifer Dean - Admin - 2323' 'Julia Roellke - 7470'
#  'Brent Boscarino - 4691' 'Nicole Sedran - 6453' 'Leah Gorman - 5069'
#  'Lars Rudstam - 8544' 'Matt Brincka - 3837' 'Robert Vasiluth - 8900'
#  'Tarki Heath - 4556' 'Karen Riva_Murray - 3344' 'Public Reports - 6034']
# ['Alex Parry - 9741' 'Ryan Fordham - 9731' 'Alaina Oughterson - 9744'
#  'Jessie Dixon - 8580' 'Luke Gervase - 9596' 'Jessica Ingham - 8025'
#  'Tyler Levy - 9838' 'Walter Dutcher - 4296' 'Tim Rice - 9742'
#  'Kristopher Williams - 9274' 'Brittney Rogers - 4361'
#  'David Andrews - 9471' 'Sarah Whitney - 12557' 'Brooke Pegher - 12592'
#  'Mary Walsh - 12415' 'Mary Walsh - 12422' 'Milt Ostrofsky - 12744'
#  'Eric Chapman - 12691' 'Robert Dillon - 12748'
#  'Collector unknown - 12539' 'Mark Lethaby - 12659' 'Tim Daley - 12790'
#  'Steven Adams - 12611' 'Jim Grazio - 12566' 'John Wallace - 12932'
#  'Representative from iNaturalist.org - 12903' 'Peter Woods - 12738'
#  'David Yeany - 12756' 'Brian Mangan - 13235' 'Aaron Jewitt - 13223']
# ['Daniel Nydick - 12749' 'Nick Macelko - 13476' 'Kevin Kelly - 12671'
#  'Christopher Tracey - 12740' 'Elizabeth Meyer - 12759'
#  'Amy Jewitt - 12931' 'Dave Rebuck - 12770' 'Rick Spear - 12773'
#  'Amy Williams - 12792' 'David Lieb - 12817' 'USGS-NAS Database - 13574'
#  'Steven Pearson - 9597' 'Jared Parsons - 16066'
#  'David  Lindeman  - 16548' 'Kathryn Monacelli - 5479'
#  'Cora Delucia - 16025' 'Emma Antolos - 4466' 'Josh Neff - 7926'
#  'Matthew Shank - 12575' 'Kyle Thaine - 16074' 'Kristen Holeck - 17825'
#  'Kristen Wilde - 6989' 'Lindsay Yoder - 9580' 'Jeffrey Burt - 18425'
#  'Andrew Turner - 12602' 'Nick Decker - 13177' 'Marc Hecht - 19784'
#  'Elizabeth Bradshaw - 19635' 'Bianca Gonzalez - 15848'
#  'Melissa Foucreau - 19636']
# ['Winston Gedicks - 9521' 'Catherine McGlynn - 2332'
#  'Jacob Cramer - 16387' 'Emma Stanczyk - 21290' 'Sean Hartzell - 21318'
#  'Sarah Coney - 8462' 'Lauren Henderson - 19154' 'Alexander Krest - 19533'
#  'Sequoia Sempervirens - 21973' 'Ty Sharrow - 20699'
#  'Zachary Pryor - 22185' 'Andrew Conboy - 20713' 'Alicia Palmer - 14331'
#  'APIPP Data Recorder - 19322' 'Phil Cwiek - 23358'
#  'Rebecca Hargrave - 2569' 'Lynne Beaty - 22966' 'Tyler Grabowski - 23959'
#  'Sam Verbeck - 23775' 'Vara Connor - 22874' 'Les Resseguie - 18751'
#  'Robert S. Whyte - 13887' 'Mark Brickner - 12782' 'Bob Mozer - 11264'
#  'Adele Philippides - 21025' 'STEPHEN Miller - 23860'
#  'Colleen Lutz - 5591' 'Sarah Pawliczak - 25355' 'Alejandro Reyes - 3777'
#  'Brian Greene - 23174']
# ['Brandon Russell - 25077' 'Maya Thompson - 23610'
#  'Abigail Bezrutczyk - 8887' 'Mark Privee - 22873' 'Josh Young - 26421'
#  'Jared Ortlieb - 27124' 'Joshua Dipaola - 24140' 'Eric Schill - 22075'
#  'Chris Leece - 19349' 'Abby Webster - 28441' 'Kimberly Schulz - 8779'
#  'Stacy Furgal - 3099' 'Sierra Stickney - 28620' 'Monica Groth - 23793'
#  'Strike Team Technician - 28619' 'Carolyn Cyr - 22588'
#  'Caleb Lines - 28775' 'NYNJTC Aquatic Invasives Strike Force - 23520'
#  'Diego Diaz - 28777' 'Devin DiGiacopo - 27768' 'Rachel Kester - 33029'
#  'Brea Arvidson - 19275' 'Gregory Lech - 13213' 'Mike Campbell - 32609'
#  'Tammara Van Ryn - 19561' 'Megan Kirby - 28868' 'Matthew Gorman - 28948'
#  'Michael Spada - 11092' 'Alisa Trudell - 28780' 'Rosie Grayburn - 35270']
# ['Eileen Fitzgerald - 35466' 'Douglas Wessells - 36323'
#  'Toland Kister - 36646' 'Julia  Luna  - 28958' 'Hannah Coppola - 21052'
#  'Lauren Mercier - 10563' 'Gage Root - 32360' 'Kirby Van Vleet - 20292'
#  'Julian Motola - 20913' 'Erica Kaczmarczyk - 37464' 'Noah Yawn - 32977'
#  'Caitlin Canario - 23811' 'Christopher  Titus - 37897'
#  'chris pennuto - 4422' 'Katherine Lawson - 37416'
#  'Meredith Taylor - 2488' 'Hannah Diebboll - 37153' 'Tyler Smith - 2085'
#  'Rachel Sysak - 3599' 'Scott Kishbaugh - 2262' 'Steven P. Grund - 12449'
#  'iNaturalist User - 12134' 'Jason Jakielaszek - 33030'
#  'Dana Holmlund - 32627']
# <ipython-input-59-9ad4f4ce9418>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rdf.rename(columns={'present_species_id':'uid', "scientific_name":"sci_name", "observation_date":"obs_date"}, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# <ipython-input-59-9ad4f4ce9418>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rdf.drop(['geometry', 'observer_name', 'jurisdiction', 'genus'], axis=1, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
url = "https://imapinvasives.natureserve.org/arcgis/rest/services/public_presence/MapServer/4" # presences
url2 = "https://imapinvasives.natureserve.org/arcgis/rest/services/public_approximate_presence/MapServer/4" # approx coordinates presences

imap_obs = {}
imap_recorders = {}

import geopandas as gpd

# convert esri date to datetime
def convert_esri_date(row):
    """Converts an esriFieldTypeDate value to a Python datetime object."""
    return datetime.datetime.fromtimestamp(row["observation_date"] / 1000)  # Divide by 1000 to get seconds

for i, (k, v) in enumerate(my_vars.items()):
  # separate list of genera
  splist = v['sci_name'].sum() # make list of all species inc. alternate scientific names
  # separate out genera with no species epithet
  hightax = []
  for item in splist:
    if len(item.split()) == 1:
      hightax.append(item)

  genus = [x.split()[0] for x in splist]

  gdf = esri2gpd.get(url, fields=['present_species_id', 'observer_name', 'observation_date', 'jurisdiction', 'genus', 'scientific_name'], where=f"genus IN {tuple(genus)} AND jurisdiction IN ('New York', 'Pennsylvania', 'Michigan', 'Ohio')")
  gdf2 = esri2gpd.get(url2, fields=['present_species_id', 'observer_name', 'observation_date', 'jurisdiction', 'genus', 'scientific_name'], where=f"genus IN {tuple(genus)} AND jurisdiction IN ('New York', 'Pennsylvania', 'Michigan', 'Ohio')")
  rdf = gpd.GeoDataFrame(pd.concat([gdf, gdf2], ignore_index=True), crs=gdf.crs)

  rdf["observation_date"] = rdf.apply(convert_esri_date, axis=1)
  rdf["observation_date"] = pd.to_datetime(rdf["observation_date"], errors='coerce')
  #QAQC
  rdf = rdf.loc[rdf['observation_date']>datetime.datetime(1970,1,1)] # drop old data

  # get potential pseudoabsences
  imi_observers = rdf['observer_name'].unique()
  print(len(imi_observers), 'observers')
  if len(imi_observers) > 30:
    obs_chunks = []
    start = 0
    end = len(imi_observers)
    step = 30
    for i in range(start, end, step):
      x = i
      observers_chunk = imi_observers[x:x+step]
      if len(observers_chunk) > 1:
        whereclause = f"observer_name IN {tuple(observers_chunk)} AND jurisdiction IN ('New York', 'Pennsylvania', 'Michigan', 'Ohio')"
      else:
        whereclause = f"OBSERVER IN ('"+observers_chunk+"') AND jurisdiction IN ('New York', 'Pennsylvania', 'Michigan', 'Ohio')"
  imi_pseudoabs = esri2gpd.get(url, fields=['present_species_id', 'observer_name', 'observation_date', 'jurisdiction', 'genus', 'scientific_name'], where=whereclause)
  imi_pseudoabs["observation_date"] = imi_pseudoabs.apply(convert_esri_date, axis=1)
  imi_pseudoabs["observation_date"] = pd.to_datetime(imi_pseudoabs["observation_date"], errors='coerce')
  imi_pseudoabs = imi_pseudoabs.loc[imi_pseudoabs['observation_date']>datetime.datetime(1970,1,1)] # drop old data
  imi_pseudoabs = pd.merge(imi_pseudoabs,rdf, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
  imi_pseudoabs.rename(columns={'present_species_id':'uid', "scientific_name":"sci_name", "observation_date":"obs_date"}, inplace=True)
  imi_pseudoabs['uid'] = imi_pseudoabs['uid'].astype(str)
  imi_pseudoabs['lat_dec'] = imi_pseudoabs['geometry'].y.astype(float)
  imi_pseudoabs['lon_dec'] = imi_pseudoabs['geometry'].x.astype(float)
  imi_pseudoabs.drop(['geometry', 'observer_name', 'jurisdiction', 'genus'], axis=1, inplace=True)
  # drop nontarget species
  rdf = rdf[(rdf["scientific_name"].isin(splist)) | (rdf["genus"].isin(hightax))]
  rdf.reset_index(drop=True,inplace=True)
  rdf.rename(columns={'present_species_id':'uid', "scientific_name":"sci_name", "observation_date":"obs_date"}, inplace=True)
  rdf['uid'] = rdf['uid'].astype(str)
  rdf['lat_dec'] = rdf['geometry'].y.astype(float)
  rdf['lon_dec'] = rdf['geometry'].x.astype(float)
  rdf.drop(['geometry', 'observer_name', 'jurisdiction', 'genus'], axis=1, inplace=True)
  rdf["source"] = "iMapInvasives"
  # all obs in layer have been confirmed

  imap_obs[k] = rdf
  imap_recorders[k] = imi_pseudoabs
# Out:
# 80 observers
# ['Robert Angyal - 2624' 'David Pawlowski - 3199' 'Stephen Walsh - 3173'
#  'Denise Clay - 2348' 'Amy Mahar - 3380' 'Stacy Furgal - 3099'
#  'Melissa Cohen - 2628' 'Brittney Rogers - 4361' 'Jeremy Dietrich - 3772'
#  'Doug Carlson - 2623' 'Scott Wells - 2656' 'Robert Schmidt - 3343'
#  'Emily Zollweg - 2659' 'Marcus Rosten - 4808' 'Brad Mudrzynski - 4546'
#  'SWFDB DEC Fisheries - 5612' 'John Farrell - 2660' 'Lucy Nuessle - 5893'
#  'Public Reports - 6034' 'USGS-NAS Database USGS-NAS Database - 6414'
#  'Kirkland Nagy - 7914' 'Alex Parry - 9741' 'John Cooper - 7454'
#  'Eric Chapman - 12691' 'Jennifer Dzimiela - 12864'
#  'Robert Morgan - 12423'
#  'Representative(s) from Gannon University - 12902'
#  'Representative(s) from PA Fish & Boat Commission - 12905'
#  'Mark Lethaby - 12659' 'Jim Grazio - 12566']
# ['Nate Irwin - 12682' 'Boris Kitevski - 13167' 'Rebecah Ford - 13589'
#  'Michael Hosack - 12669' 'Robert Wnuk - 12923' 'Jay Stauffer - 13678'
#  'USGS-NAS Database - 13574' 'Nick Macelko - 13476'
#  'Matthew Shank - 12575' 'Emily Sheridan - 3107' 'Bianca Gonzalez - 15848'
#  'Luke Gervase - 9596' 'Gary Smith - 12976' 'Jessica Newbern - 13419'
#  'Les Resseguie - 18751' 'Bob Reiter - 21681' 'Observer Unknown - 24082'
#  'Erin Vennie-Vollrath - 5136' 'Donald Kretser - 23899'
#  'Sean Hartzell - 21318' 'Michael Morgan - 3273'
#  'Kristopher Williams - 9274' 'Justin Noble - 24320'
#  'Josh Brandle - 24391' 'Angela Cook - 24411' 'Emily Emanuel - 24597'
#  'Kyle Zastrow - 25143' 'S T - 25165'
#  'Representative from Philadelphia Water Department - 26635'
#  'Francis Jones - 26643']
# ['Leslie Degen - 26644' 'Dan Powell - 26661'
#  'DEC DMR Marine Fisheries Database Generic Observer - 26424'
#  'Kyle  Glenn  - 29736' 'Veronica Mileski - 29534' 'Deon Dedeaux - 32470'
#  'Kari Minissale - 32341' 'Thad Yorks - 7950'
#  'Jennifer Dean - Admin - 2323' 'Jamie Jensen - 36708'
#  'Aaron Small - 37283' 'Travis Cornell - 37389' 'kevin Lynch - 37454'
#  'Alexa Howansky - 28804' 'Alexander Goldsmith - 37718'
#  'Sean Bird - 38288' 'Michael DiSarno - 38663'
#  'Representative(s) from Academy of Natural Sciences - 12910'
#  'Collector unknown - 12539' 'Chuck Brice - 26671']
# /usr/local/lib/python3.11/dist-packages/esri2gpd/core.py:91: UserWarning: Long download time — total download will require 61 separate requests
#   warnings.warn(
# 893 observers
# ['Robert L. Johnson - 2251' 'Stacy Furgal - 3099'
#  'Nancy Davis-Ricci - 2196' 'Janet Andersen - 2359'
#  'Meghan Johnstone - 3208' 'Mike McHale - 3108' 'Mike Goehle - 2611'
#  'Hilary Smith - 2303' 'Denise Clay - 2348' 'Greg Chapman - 3100'
#  'Emily Sheridan - 3107' 'Paul Marangelo - 15165' 'Jeff Sann - 3106'
#  'Scott Kishbaugh - 2262' "Heidi O'Riordan - 3281"
#  'Samantha Knowlden - 2433' 'Meg Wilkinson - 2084' 'Nancy Engel - 2511'
#  'Chuck Nichols - 3330' 'William Hoffman - 3168' 'Julie Nace - 3498'
#  'Kelly McDonald - 4071' 'Gail Meyer - 3182' 'Lawrence Eichler - 2255'
#  'Willard Harman - 3133' 'Heather Ruel - 2587' 'Alexis Alvey - 3283'
#  'Chris Lajewski - 2302' 'Alyssa Reid - 3025' 'Michael Goethle - 2121']
# ['Lindsay (Jody) Hoyt - 3750' 'Kevin Jennings - 3033'
#  'Marisa Kwoczka - 2529' 'Holly Menninger - 2247' 'Ariana Newell - 2377'
#  'Donna Vogler - 2395' 'Walt Nelson - 2283' 'David Newman - 4221'
#  'John Davis - 2452' 'Erik Posner - 3187' 'Kersten Laveroni - 3878'
#  'Meredith Taylor - 2488' 'Laurel Engelsson - 3867' 'Jerry Jenkins - 3881'
#  'Mathew Shawl - 3761' 'George Profous - 4194' 'Brad Wenskoski - 2732'
#  'Laurel Mann - 4342' 'Mark Rooks - 3983' 'Zachary Simek - 4559'
#  'Linda Ziemba - 4055' 'Deborah Hoppe - 4579' 'Logan West - 4562'
#  'Jennifer Schlick - 4564' 'Scott Ingmire - 4553' 'Frank Baehre - 3966'
#  'Kathy Schwager - 2086' "Robert O'Brien-OPRHP - 2280"
#  'Unknown Palmer - 2927' 'Steven Glenn - 3047']
# ['Tyler Smith - 2085' 'Unknown Pokorny - 2673' 'Susan Dobbertin - 2136'
#  'Elisha Gibson - 2140' 'Connie Tedesco - 2396' 'Unknown Buck - 2815'
#  'Laurie Freeman - 3367' 'Steve Glenn - 2160' 'Devin DuCeour - 2137'
#  'David Werier - 2080' 'Francine Stayter - 4306' 'Mary Binder - 4440'
#  'George Robinson - 4770' 'Steve Young - 2192' 'Paris Harper - 4872'
#  'Casey Holzworth - 2559' 'Bill McGhie - 4917' 'Cathy Matier - 4918'
#  'Bonnie Parton - 2368' 'Andrea Locke - 4707' 'Brad Mudrzynski - 4546'
#  'Elizabeth MacEwen - 5155' 'Sabrina Dreythaler - 5154'
#  'Michael Hough - 4532' 'Lorraine Skibo - 5195' 'Angela Driscoll - 4775'
#  'Kaleb Stores - 4792' 'Will Novitske - 12758' 'John DeHollander - 2714'
#  'Gabe Piazza - 5067']
# ['John Pokrzywka - 5050' 'Ian Schultz - 4426' 'Andrew Stadler - 5033'
#  'Dan_10 Rockefeller - 4974' 'Matt Frye - 3244'
#  'Erin Vennie-Vollrath - 5136' 'Guy Middleton - 2985'
#  'Kim Sherwood - 5363' 'Angie Martin - 4664' 'Kristina Younger - 5236'
#  'Victor Lamoureux - 5361' 'Jim Eckler - 3194' 'Bill Wolanske - 4964'
#  'Brenda Weaver - 4529' 'Mr. Slyer Classes Slyer Science Classes - 5447'
#  'Cara Lee - 2062' 'Kathryn Monacelli - 5479' 'Kristen Mooney - 5349'
#  'Hillary Siener - 5464' 'David Thomas-Train - 3719' 'Kali Bird - 3463'
#  'Daniel Kopec - 5554' 'Kristen Brewster - 5337' 'Eric Randall - 4039'
#  'Jessi Lyons - 2493' 'Spider Barbour - 2042' 'Shane Gebauer - 2054'
#  'Timothy Howard - 2056' 'Troy Weldy - 2079' 'Betty Ketcham - 2060']
# ['Adele Olivero - 2066' 'Greg J. Edinger - 2046' 'Andy Nelson - 2065'
#  'Elizabeth Spencer - 2071' 'Jennifer Garrett - 2053'
#  'Aissa Feldmann - 2050' 'Richard Ring - 2068' 'Kelly Perkins - 2199'
#  'Don Faber-Langendoen - 2049' 'Julie A. Lundgren - 2063'
#  'Kimberly Smith - 2200' 'Heidi Himes - 5643' 'David Hunt - 2057'
#  'Luke Wlasniewki - 5912' 'Leif Love - 5927' 'Caitlin Muller - 6021'
#  'Mat Levine - 3039' 'John Farrell - 2660' 'Benjamin Hansknecht - 6042'
#  'Katie McCann - 5928' 'Michael Parisio - 5922' 'Lucy Nuessle - 5893'
#  'Patty Wakefield-Brown - 5647' 'Holly Waterfield - 3135'
#  'Don Fisher - 5450' 'Emily Staychock - 5152' 'Michele Wunderlich - 2731'
#  'Marilyn Jordan - 2142' 'Nancy Stock - 6319' 'Joseph Clark - 6198']
# ['Hilary Mosher - 4778' 'Selma Rosenthal - 5807' 'William Wellman - 2977'
#  'Public Reports - 6034' 'Leigh Walrath - 3523' 'KG Karol - 6459'
#  'N Trigoboff - 6483' 'L Klotz - 6484' 'H Meyer - 6487'
#  'Robin Sleith - 6488' 'Chris Graham - 6412' 'Erik Kiviat - 2272'
#  'USGS-NAS Database USGS-NAS Database - 6414' 'Michael Sowinski - 6417'
#  'Michael Rider - 6320' 'Jacob Runner - 3666' 'David Kelley - 6031'
#  'George Stowers - 6871' 'Brian Schneider - 6936' 'April Brun - 6794'
#  'Fred Hensen - 2649' 'Daniel Langer - 6376' 'Jennifer Clark - 6824'
#  'Stephanie Larkin - 3032' 'Ashley Gingeleski - 6858'
#  'Laurel Gailor - 3111' 'Matt Brincka - 3837' 'Brendan Quirion - 2095'
#  'Colleen Lutz - 5591' 'Phillip Bonn - 6941']
# ['Renee Jensen - 7093' 'Roy Widrig - 4557' 'Sundas Rehman - 5633'
#  'Samantha Epstein - 5434' 'Ian Sansone - 6763' 'Tyler Christensen - 5724'
#  'Emily Dyett - 6829' 'Taylor Ouderkirk - 6783' 'Briggette Roos - 6813'
#  'Elyse Henshaw - 4966' 'Michelle Henry - 7147'
#  'Alexandra M. Corsini - 7181' 'Heather E. Maranville - 7193'
#  'Solitude Lake Management Data Set - 7546'
#  'DEC Lake Monitoring Data - 7053' 'Amy Mahar - 3380'
#  'Rebecca Pinder - 8009' 'Karen Terbush - 4952' 'Eric Jabot - 7119'
#  'Class Account Scotia-Glenville MS - 7693' 'Bobby Lemieux - 7916'
#  'Elisabeth Boemark - 7913' 'Ken Belfer - 7948' 'Ernest Coon - 7983'
#  'Derek Hilton - 8295' 'Sarah Crawford - 8296'
#  'Alexandra Henderson - 6874' 'Sue Gregoire - 6399'
#  'Patricia Shulenburg - 4450' 'Shaina Johnson - 6888']
# ['Emma Antolos - 4466' 'Alivia Sheffield - 8285' 'Kevin Sanders - 7017'
#  'Christopher Mitchell - 8227' 'Elizabeth Sammons - 6935'
#  'Tom Phillips - 8079' 'Morgan Motherwell - 8410' 'Joellen Lampman - 4879'
#  'Megan Phillips - 5025' 'Frederick Pintz - 8399'
#  'Elizabeth Blaschak - 7919' 'Amy McGinnis - 4640' 'John Thompson - 2074'
#  'Finger Lakes Macrophyte Survey Monitoring Program - 8575'
#  'Leah Gorman - 5069' 'Sean Benninger - 7918' 'Terry Smith - 8618'
#  'Paul Lord - 2274' 'Emily Carrollo - 8136' 'Pam Aprilliano - 8406'
#  'Steve Case - 3976' 'Sean Regalado - 5465' 'Bruce Friedmann - 3671'
#  'Philip Bossert - 6788' 'Heather Zimba - 6912' 'Sara Hill - 8713'
#  'Larry Litwin - 8740' 'Brittney Rogers - 4361' 'Eric Struening - 6086'
#  'Bryna Daykin - 8319']
# ['Alicia Wood - 8456' 'Nicholas Terracciano - 8773'
#  'Marilyn Fancher - 8565' 'Aaron Heminway - 6379' 'Spencer Barrett - 8003'
#  'Travis Ganter - 4354' 'Crystal Decker - 4355' 'Laura Cowger - 8438'
#  'John Lang - 6970' 'Matthew Paufve - 8301' 'John Butler - 9076'
#  'Ashley Leemans - 9533' 'Jason Hanselman - 9736' 'Luke Gervase - 9596'
#  'Tyler Levy - 9838' 'Tessa Artruc - 9743' 'Shaina Babcock - 9738'
#  'Tim Rice - 9742' 'Jennifer Dean - Admin - 2323'
#  'Elizabeth Truskowski - 9931' 'Christina Kolmann - 9950'
#  'Elizabeth-Ann Jamison - 9730' 'Kristopher Williams - 9274'
#  'Walter Dutcher - 4296' 'Jessica Ingham - 8025' 'Alex Parry - 9741'
#  'Jay White - 8969' 'Sarah Kirkpatrick - 9951' 'Brittany Lagaly - 9169'
#  'Zac Falconer - 9949']
# ['Lindsay Yoder - 9580' 'Alexandra Krohn - 9773'
#  'Kerry Crowningshield - 7783' 'Jessie Dixon - 8580'
#  'Michael Parker - 2725' 'Steven Pearson - 9597' 'Tyler Duby - 9772'
#  'Chelsea Cannon - 10099' 'Marcus Rosten - 4808' 'Sarah Ganter - 9760'
#  'Anne Rhoads - 9237' 'Jennifer Dunn - 3801' 'Scott Cornett - 2626'
#  'Rebecca Mann - 9560' 'Scott Proctor - 5875' 'Falon Neske - 9338'
#  'Lem Hegwood - 10310' 'Gwendolyn Temple - 6754' 'John Marino - 8933'
#  'Mary Beth Mylott - 10168' 'Craig Jackson - 8674' 'Larry Master - 2456'
#  'Lawrence Rossini - 5466' 'Anthony Dolce - 10521' 'Lynn Bogan - 3191'
#  'David Andrews - 9471' 'Jayla White - 10211' 'Kierstin Carlson - 12416'
#  'Sarah Ernst - 12448' 'James K. Bissell - 12435']
# ['William Harrison - 12451' 'Steven P. Grund - 12449'
#  'Brosi A. Bradley - 12440' 'M. Loree Speedy - 12445'
#  'Lindsey Miller - 12444' 'Sara V. Parker - 12447'
#  'Frederick H. Utech - 12430' 'M. Polechko - 12516'
#  'Sarah Whitney - 12557' 'Gretchen Schatschneider - 12561'
#  'Amy Jewitt - 12931' 'Tim Wood - 12614' 'Barbara Lathrop - 12559'
#  'Kevin Kelly - 12671' 'Steve Means - 12649' 'Sherry Leap - 12757'
#  'Glenn Sullivan - 12860' 'Peter Woods - 12738' 'Andrew Zadnik - 12771'
#  'Robert Harris - 12816'
#  'Representative(s) of Weed Warriors (Presque Isle) - 12911'
#  'Jean Gomory - 12933' 'Allison Sanderson - 12914'
#  'Krista Scheirer - 12869' 'Sara Stahlman - 12560'
#  'Brian Pilarcik - 12916' 'Fawn Kearns - 12921' 'Ron Keeney - 12918'
#  'Daniel Bickel - 13224' 'Jessie Kemper - 13057']
# ['Representative(s) from Princeton Hydro - 13098'
#  'Michael Hartshorne - 13082' 'Jim Grazio - 12566' 'Diana Restifo - 13110'
#  'William Kirkpatrick - 13171' 'Kevin Hess - 12721' 'Rachel Reese - 12872'
#  'Alan Everett - 12800'
#  'Representative(s) from Natureworks, Clear Water Associates, Inc. - 13179'
#  'Dean Jones - 1294' 'Robert Booth - 13258' 'Nick Decker - 13177'
#  'John Levitsky - 13009' 'Dwayne Hess - 13248' 'Jamie Knecht - 13288'
#  'Jodi Sulpizio - 13322' 'Kim Van Fleet - 13427' 'Mary Walsh - 12415'
#  'Nick Macelko - 13476' 'Meghan Rogalus - 12586'
#  'Jeanette Girosky - 12610' 'Becky Lynn Travis - 13601'
#  'Stacie Hall - 12947' 'Mark Warman - 13311' 'Trish Harrington - 13739'
#  'Autumn Thomas - 13387' 'Jessica McPherson - 12556'
#  'Collector unknown - 12539' 'USGS-NAS Database - 13574'
#  'Nick Trivelli - 13839']
# ['Jim Walter - 13825' 'Edward Phalen - 13886' 'Gregory Lech - 13213'
#  'Kent Taylor - 13795' 'Robert S. Whyte - 13887' 'William Gleason - 12450'
#  'J. W. Fetzner - 14039' 'Alejandro Reyes - 3777' 'John MarinoL2 - 10333'
#  'Kenneth Hawks - 4754' 'Bianca Gonzalez - 15848' 'Jeff O Handley - 4631'
#  'Trea Schumacher - 16017' 'Ralph Green - 15951' 'Jared Parsons - 16066'
#  'Jason Kappan - 15959' 'Robert Merritt - 15948' 'Krista Scheirer - 16315'
#  'Anna Kuhne - 9638' 'Katelin Quarles - 15913' 'Lauren Mercier - 10563'
#  'Paulina Murray - 7654' 'Frank Williams - 7000' 'Grace Bichler - 16064'
#  'Ashley Aupperle - 11178' 'Jeremiah Martin-Johnson - 16518'
#  'Thomas Simmons - 10259' 'Rebekah Pauley - 16188'
#  'Jessica Newbern - 13419' 'Teresa Pfeifer - 16693']
# ['Emily Harrower - 15924' 'Gerhard Schlingmann - 16706'
#  'Scott Kishbaugh - 16730' 'Cora Delucia - 16025' 'Mary Keefe - 15981'
#  'Jannell Nickols - 16112' 'Nicole White - 16784' 'Everett McNeill - 8690'
#  'Richard Hadcock - 16803' 'Keri VanCamp - 8076' 'David Kelley - 16107'
#  'Julia R Gerard - 9408' 'Felicia Lamphere - 13977'
#  'Margaret  Butler - 16923' 'Victoria Herkalo - 16766'
#  'Jeremy Miller - 16564' 'Nancy VanCott - 16968' 'William McAdoo - 16995'
#  'Josh Neff - 7926' 'Jessica Goretzke - 7895' 'Kristin Fitzgerald - 6258'
#  'Joseph  Perrelli - 16990' 'Ryan Elliott - 7478' 'Ally Jones - 17118'
#  'R H - 17142' 'Cindy Rider - 11396' 'Rick Gerardi - 17163'
#  'Observer Unknown - 269' 'Taylor West - 17159' 'Cara Sherman - 16717']
# ['Karen Terbush - 16816' 'Cathy Pedler - 5026' 'Stephanie June - 15949'
#  'Krystal Piucci - 17220' 'John Ozard - 17531' 'Laura Bailey - 6642'
#  'Kyle Thaine - 16074' 'Brian Henry - 17236' 'Matthew Kraft - 15548'
#  'Mark Whitmore - 2296' 'Thomas Wynne - 17834' 'Meg Janis - 2346'
#  'Nicole DeCarolis - 17925' 'Bill Jacobs - 2141' 'Ashley Young - 10353'
#  'daniel laury - 17850' 'Brian Siklinski - 5055' 'Irene Holak - 9966'
#  'Kristen Wilde - 6989' 'Lindsay Charlop - 17204'
#  'Zachariah Glaspy - 7824' 'Adam Lamancuso - 16218' 'Ellen Collins - 3616'
#  'Marcus Harazin - 5264' 'Lindsey Duval - 18717' 'Jared Bedient - 10081'
#  'Daina Krumins - 15753' 'Justin SEMKE - 19448' 'Michael Kastan - 19374'
#  'Melissa Foucreau - 19636']
# ['Christopher Mazzeo - 19637' 'Kayla Lenway - 19633' 'Devin Smith - 16817'
#  'Lauren Henderson - 19154' 'Steven Anthony - 19619'
#  'Daniel Sorensen - 13159' 'Nicole Campbell - 7176'
#  'Elizabeth Bradshaw - 19635' 'Alex Linerode - 19694'
#  'Amanda Helseth - 19221' 'Sierra Stickney - 19576'
#  'Ashley Morris - 19032' 'Ross McLennan - 16971' 'Sarah Coney - 8462'
#  'Alexander Krest - 19533' 'Sam Schultz - 9924' 'Emma Sarnacki - 20171'
#  'Jeremy Woolson - 18720' 'Kurt Jirka - 20239' 'Kurt Moser - 20241'
#  'David Nelson - 20266' "Mitchell O'Neill - 18716"
#  'Louisa Sorriento - 8728' 'Sara Stebbins - 19541' 'Ed Hawkey - 20216'
#  'Paula Walter - 20137' 'Thomas Starkey - 7344' 'Kelsea Rogers - 18606'
#  "CLAIRE O'NEILL - 18686" 'Joyce Tomaselli - 4537']
# ['Stephen Litwhiler - 3893' 'Thomas Smith - 20662'
#  'David R. Fowler - 13569' 'Monica Caves - 9473'
#  'Garrett Chisholm - 18757' 'Gavin Berdan - 20604' 'Alex Stalica - 20603'
#  'John Titus - 20761' 'Winston Gedicks - 9521' 'Danielle Dolan - 19681'
#  'Tessa Pemrick - 17669' 'Mark Teece - 20852' 'Michael Giambalvo - 19981'
#  'Mikael Ann Melfi - 19588' 'Kimberly Fortune - 20897'
#  'winnona brust - 20900' 'Sarra Learned - 20738' 'Eva Carman - 20869'
#  'Donald Kerr - 20916' 'Nelson Dumas - 7096' 'Jacob Cramer - 16387'
#  'Jill Bilodeau - 21221' 'Hannah Bequeath - 20892'
#  'Justin Searles - 19615' 'Nancy Clarke - 20988' 'Tarki Heath - 4556'
#  'Megan Pistolese - 4365' 'Nicole Carville - 21677'
#  'Leigh Walrath - 15829' 'Nick Smith - 21844']
# ['Laura Shappell - 6374' 'Sonia Sandoval - 7130' 'Janelle Jones - 7601'
#  'Alexis Bashta - 19846' 'Andrew Glaspell - 21859'
#  "Azure D'Angelo - 19847" 'Charles Reick - 21861'
#  'Courtney Renner - 21862' 'Hannah Foster - 21863'
#  'Jennifer Kelly - 21370' "Jennifer O'Shea - 9470" 'Kaitlin Fello - 21864'
#  'Kori Malsegna - 19845' 'Lindsay McMillan - 7505' 'Maria Vidal - 21865'
#  'Megan Harris - 19842' 'Megan Swing - 19657' 'Phil Simmons - 21866'
#  'Stuart Messur - 21867' 'Victoria Tidball - 21868' 'Rich Adams - 21881'
#  'Lynn Klotz - 8616' 'Jennifer Bailey - 15979' 'Dan Corbett - 21368'
#  'Michael Yost - 21373' 'William Ebert - 8624' 'Emelia Yost - 10079'
#  'Sam Shephard - 16160' 'Matthew Gallo - 21992'
#  'Jonathan Townsend - 16187']
# ['APIPP Data Recorder - 19322' 'Jeff Tome - 18721'
#  'iNaturalist User - 12134' 'Maxine Hill - 23026' 'Ava L - 18755'
#  'Alexis  Tate - 23282' 'Sean Hartzell - 21318' 'Thomas Firkins - 22872'
#  'Patrick Bly - 22875' 'Adirondack Research Generic Observer - 22879'
#  'Vara Connor - 22874' 'Mark Privee - 22873' 'Clara Lloyd - 19902'
#  'Brian Greene - 23174' 'Ty Sharrow - 20699' 'Connor Curley - 23616'
#  'Jennie Suchewski - 23619'
#  'NYNJTC Aquatic Invasives Strike Force - 23520'
#  'Madison Michetti - 23747' 'Christian Brashear - 17730'
#  'Mary Beth Kolozsvary - 3399' 'Intern Prism - 22552'
#  'Sheila Sicilia - 3979' 'Colleen Andrews - 23885'
#  'Kayanne Gsellmeier - 23933' 'Cindy Major - 16529' 'Sydney Aveson - 8676'
#  'Christina VanDusen - 19530' 'Shelby Crawford - 23772'
#  'Brian Daggs - 23757']
# ['Alexandra Mitchell - 19659' 'Will Parker - 23796'
#  'Generic Survey123 User - 20133' 'Ezra Schwartzberg - 3971'
#  'Trudy Rowe - 3665' 'Matthew Biondolillo - 19493'
#  'Madeline Maitino - 16092' 'Jacob Moore - 23244' 'Jessica Kester - 13632'
#  'Julie Romano - 24388' 'Buffer Steward  Chenango County SWCD - 24318'
#  'Historical DEC Generic Observer - 24174' 'Andrew Conboy - 20713'
#  'Nikki Nowak - 24236' 'Gregory Zuill - 23245' 'Steven Daniel - 18356'
#  'Deaglan McManus - 13740' 'Toni Peterson - 24115' 'Mark Gibson - 23844'
#  'Emily Thiel - 9561' 'Abby Lanterman - 20060' 'Mary Greagan - 9127'
#  'Cathy Marczyk - 24558' 'Jerry Chiocchio - 24589' 'Evan Bennett - 23448'
#  'Ross Abbett - 24456' 'Brad Cramer - 21979' 'Madeline Ebert - 19663'
#  'Chris Bryant - 23451' 'Elizabeth Snow - 24286']
# ['Paul Siskind - 8662' 'Jessica Hicks - 23748' 'STEPHEN Miller - 23860'
#  'Ann Rhoads - 13183' 'Emily Timkey - 19692' 'Dan Belliveau - 24452'
#  'Haley Gladitsch - 22236' 'Andrew Randazzo - 15728' 'Carole Henry - 9629'
#  'David Carr - 10459' 'SOLitude Lake Management Generic Observer - 24827'
#  'Marty Miesko - 25111' 'Mary Underhill - 2561' 'Liz McCheyne - 23131'
#  'Peter Lombardi - 25087' 'Rose Helmer - 24785' 'Barry Ceci - 25374'
#  'Hannah Coppola - 21052' 'Janice Reynen - 22687' 'Robert Smith - 16532'
#  'Kathleen McGrath - 9123' "Jim D'Angelo - 24117" 'Patricia Bedard - 8458'
#  'Catherine McGlynn - 2332' 'Sonya Bayba - 21634' 'Amy Funkhouser - 23100'
#  'Elaina McCartney - 23854' 'Nicole Smeenk - 16162'
#  'Matthew Dombrowski - 26651' 'Rocky Gleason - 22169']
# ['Michael Beahm - 26562' 'Abigail Bezrutczyk - 8887' 'Jesse Keltz - 26829'
#  'Alene Onion - 6925' 'Rebecca Gorney - 5556' 'Jeff Lojpersberger - 26830'
#  'Josh Young - 26421' 'Susan Lynch - 27561' 'Lura Johnson - 26420'
#  'Timothy Murphy - 26422' 'Erin Siebert - 22004' 'Emma Wilber - 21915'
#  'Chris Graham - 27820' 'Andrew Turner - 12602' 'Sydney VanWinkle - 10488'
#  'Jakob Scholeno - 23794' 'Dorothea Mildenberger - 23799'
#  'Molly Giles - 28729' 'Sierra Stickney - 28620' 'Justin Lamie - 23243'
#  'Caleb Lines - 28775' 'Strike Team Technician - 28619'
#  'Martha Suquet - 29100' 'skyler braeges - 24127' 'Ed Filip - 12789'
#  'Nicholas Klock - 23901' 'Joshua Neff - 23828'
#  'Caroline Franczak - 23792' 'Monica Groth - 23793' 'Connor  Vara - 29183']
# ['Kevin Musser - 29132' 'eric eagan - 29347' 'Scott Bush - 12645'
#  'Jay Chapman - 5839' 'Nicole Cassella - 29422' 'ACNC  Jamestown - 29001'
#  'Jade LaRock - 27551' 'Priscilla Titus - 4946' 'Michael Robinson - 27165'
#  'Karen Fusco - 29512' 'Richard Brown - 29553' 'Glenn Sullivan - 7944'
#  'Twan Leenders - 28937' 'Michael Robinson - 26637'
#  'Matthew Gorman - 28948' 'Kristen Shand - 24673'
#  'William Ellsworth - 4550' 'Mike Ackley - 29778' 'Sydney Tredo - 28932'
#  'Adellia Baker - 20258' 'Casen Weeden - 28599' 'Jon Titus - 4945'
#  'Eric Maringer - 29847' 'Judy Dobles - 24518' 'Forrest Gifford - 28776'
#  'Alexa Howansky - 28804' 'Maya Thompson - 28509' 'Daina Krumins - 20202'
#  'Diego Diaz - 28777' 'Lois Campbell - 30054']
# ['Jesse  Stevens - 20578' 'Ausable River Association  - 15912'
#  'Kristin Ching - 28773' 'Renee Wickman - 19513'
#  'Alyssa Schoenfeldt  - 29304' 'Michaela Otis - 30106'
#  'Timothy Bechard - 30100' 'Megan Kirby - 28868' 'Jerry Weber - 29910'
#  'Adam Hess - 29005' 'Elizabeth Kunze - 29059' 'Antoinette Miller - 29056'
#  'Steve Fulton - 24267' 'Dorene McCann - 29575'
#  'Abigail Van Slyke - 30169' 'Vincent Manuella - 20809'
#  'Sam Burrell - 5082' 'William Snyder - 10819' 'Anne Klingensmith - 30240'
#  'Kenneth Brownell - 28649' 'Joyce Brunet - 30090'
#  'Cortney VanCour - 30289' 'Devin DiGiacopo - 27768' 'Tobyn Olds - 28489'
#  'Joseph Opferman - 30467' 'Heather Platt - 29232' 'Dan Smith - 10812'
#  'Tyler Harrington - 25630' 'Michelle McGill - 28883'
#  'Julia Bugayov  - 22805']
# ['Joan Hodges - 28884' 'Brianna Saylor - 20485' 'Luke Thompson - 28714'
#  'Zach Nyhart - 28709' 'Nate Hartley - 18922' 'Leslie Surprenant - 2300'
#  'Hillary Kenyon - 22272' 'Aurora Kuczek - 23797' 'Evan Spencer - 28691'
#  'Meghan Bargabos - 28810' 'Kevin Dernier - 29227' 'Beth Fisher - 28708'
#  'Clarissa A Longoria - 28961' 'Masen Sharpe - 28674'
#  'Mia  Walton  - 29113' 'Dan Woltmann - 29085' 'Isaiah Johnson - 27795'
#  'Michele Curry - 31986' 'Beatrice Moss - 31899' 'Gary Robusto - 27391'
#  'Ning Zou - 32741' 'Catherine Farrell - 28548' 'Dana Holmlund - 32627'
#  'Justin  Zito - 32673' 'Representative from iNaturalist.org - 12903'
#  'Noah Yawn - 32977' 'Mitchell Meuser - 32979' 'Anna Trombetta - 32675'
#  'Rachel Rowlee - 32751' 'Leigh Walrath - 33209']
# ['Valerie Ellison - 32718' 'Michael Mamone - 33118'
#  'Jessica Pyrda - 33338' 'Nick Zamelis - 32752' 'Brea Arvidson - 19275'
#  'Mary Hawkins - 33513' 'Danielle Rhea - 17499' 'Robert Rahm - 30690'
#  'Alyvia Nazak - 33205' 'Amy Slentz - 31615' 'Meghan Sambrook - 33468'
#  'Rachel Taylor - 30957' 'Matthew Simonds - 33652' 'Melody Penny - 27939'
#  'Marshall Lefebvre - 7708' 'kimberly smith - 33834'
#  'Matthew Boylan - 31771' 'Penny Gould - 8392' 'Julianna Skill - 27708'
#  'USDA-FS Finger Lakes National Forest Generic Observer - 33406'
#  'Bonnie L. Isaac - 12427' 'Erin Norton - 26825'
#  'Chelsea Broughton - 31681' 'Alejandro Reyes - 31230'
#  'Warren County GIS and Lake Associations Generic Observer - 34025'
#  'Susan Rdzanek - 34206' 'Lillian Forward - 34231'
#  'Chris Halliday - 26579' 'Jcswcd Jcswcd - 31845' 'Keith McKeever - 34731']
# ['Grace Rau - 34806' 'Adam McIntyre - 32762' 'Wenchengyuan Hu - 33094'
#  'Amanda Cooper - 31394' 'Markus Shearer - 34670'
#  'Eileen Fitzgerald - 35466'
#  'Fort Drum Field Crew Generic Observer - 38772'
#  'Allied Biological Generic Observer - 36383' 'Angela Spagnoli - 36736'
#  'Morgan Hilliard - 32396' 'Justin Wolford - 21136' 'Tucker Wells - 32469'
#  'Gage Root - 32360' 'Tucker Jakobe - 32622' 'Julia  Luna  - 28958'
#  'Zoe Fox - 36645' 'Kelly Mcnamara  - 36648' 'Christina Arroyo - 36625'
#  'Corey Matthews - 37015' 'Jay Young - 29872' 'Buffer Steward - 37069'
#  'Megan Spring - 36886' 'Madelynn Ackley - 28712' 'James Wagner - 37345'
#  'Jimi Wiggins - 31956' 'Karen  Campbell - 24850' 'Chris Emerson - 36530'
#  'Alex McGraw - 37475' 'Brad Baldwin - 34693' 'Nino Polidori - 37422']
# ['Zoe Meyer - 36588' 'Judson Dasno - 28798' 'Robert Fournier - 29848'
#  'Adrian Cattell - 31072' 'Brian McAllister - 36837'
#  'Abigail Kaurin - 36575' 'Kristen Haynes - 26349' 'Scott Mulcahy - 37423'
#  'Anna Haws - 36281' 'Louis DECUNZO - 37351' 'Dylan Elman - 37623'
#  'Donna Coffey - 33176' 'Caitlin Canario - 23811' 'Benton McGowan - 32847'
#  'Camille Caceci - 19037' 'Carlo Owen Lorenzetti - 34078'
#  'Lukas Rood - 27569' 'Penny Adler-Colvin - 29417'
#  'Edward Woltmann - 37813' 'Mary Ann Benacci - 37851'
#  'Lara Hargrave - 37550' 'Christine  Venery  - 37848'
#  'Dominic Peters - 24584' 'Leonard Schantz - 10456' 'Brad Cramer - 21948'
#  'Nicholas Farese - 36229' 'Michael Fogarty - 38038'
#  'Abigail Paro - 36716' 'Jason Luce - 4677' 'Mike Voorhees - 21250']
# ['Colleen Keefer - 9498'
#  'United States Army Corps of Engineers (USACE)  Generic Observer - 38124'
#  'iNaturalist User [NY] - 20882' 'Tracey Toufali - 24902'
#  'Tristan Jaeger - 37117' 'Gage Altman-Lewis - 36991'
#  'Kassidy Robinson - 31388' 'Mark Kirwan - 32887' 'Jillian Harris - 7173'
#  'Tyler Harrington - 30638' 'Abigail Minnekine - 35101'
#  'Emily Rando - 36672' 'Jet Meyer - 32848' 'Noah Blocher - 36673'
#  'Sam Busco - 21139' 'Elisabeth Bata - 32878' 'steven altrieth - 32990'
#  'Yuriy Litvinenko - 15775' 'Hilary Cresko - 36086'
#  'Rebecca Ferry - 19499' 'Andriy Gura - 29505' 'Katrina Hanley - 33881'
#  'Douglas Knoph - 20109' 'Kaitlyn Cunningham - 24283' 'Taylor Dee - 29064'
#  'Edward Budai - 28819' 'Keith Kanoti - 31396' 'Ella Kehl - 36924'
#  'Heidi Krahling - 2478' 'Norma L. Kline - 12555']
# ['Charles W. Bier - 12441' 'Joe A. Isaac - 12432' 'Robert B. Coxe - 12446'
#  'Sue Thompson - 12426' 'Ted J. Grisez - 12534'
#  'Allison W. Cusick - 12436' 'R. C. Leberman - 12521' 'H. Kline - 12487'
#  'John R. Kunsman - 12443' 'Robert S. Mulvihill - 12452'
#  'J. M. Eggers - 12496' 'Jeffrey D. Wagner - 12442'
#  'Mark Stockley - 13035'
#  'Representative(s) from Department of Conservation and Natural Resources - 12953'
#  'Dan Farnham - 13184' 'Timothy Block - 12899'
#  'D. A. Hewitt and A. E. Schuyler - 13186' 'Timothy C. Plowman - 13379'
#  'Mark Simonis - 13383' 'W. J. Harrison - 14022' 'W. Novitske - 14151'
#  'L. Speedy - 14242' 'Cheryl Snyder - 12832']
# <ipython-input-43-2b88d9cce6af>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rdf.rename(columns={'present_species_id':'uid', "scientific_name":"sci_name", "observation_date":"obs_date"}, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# <ipython-input-43-2b88d9cce6af>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rdf.drop(['geometry', 'observer_name', 'jurisdiction', 'genus'], axis=1, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# 204 observers
# ['Meghan Brown - 3011' 'Dave Strayer - 3143' 'David Thompson - 13893'
#  'Alexander Karatayev - 3510' 'Mike McHale - 3108' 'Donna Vogler - 2395'
#  'Emily DeBolt - 17819' 'Amy Mahar - 3380' 'Mike Ellrott - 3236'
#  'Doc Bayne - 3861' 'Bruce Natale - 2751' 'Nancy Engel - 2511'
#  'Kristen Rohne - 2740' 'Jeff Corser - 2195' 'Meg Modley - 3258'
#  'Luke Myers - 3977' 'Bradley Bowers - 3127' 'Julie A. Lundgren - 2063'
#  'Derek Conant - 3670' 'unknown Austerman - 3518' 'Jesse Jaycox - 2552'
#  'Willard Harman - 3133' 'Russell Nemecek - 4088' 'Doug Carlson - 2623'
#  'Casey Holzworth - 2559' 'Cody Mendoza - 3396' 'Jordan Youngmann - 4446'
#  'Edward Levri - 12746' 'Robert Schmidt - 3343' 'Jeremy Dietrich - 3772']
# ['Bob Daniels - 3252' 'Diana Heitzman - 3512' 'Cameron Jenness - 4661'
#  'Francine Stayter - 4306' 'Damian Griffin - 3488'
#  'Michele Wunderlich - 2731' 'Elizabeth MacEwen - 5155'
#  'Fredric Dunlap - 4196' 'Samantha Olsen - 5309' 'Eric Holmlund - 2304'
#  'John Slyer - 5430' 'Tom Brooking - 6113'
#  'USGS-NAS Database USGS-NAS Database - 6414' 'April Brun - 6794'
#  'David Newman - 4221' 'Emily Dyett - 6829' 'Erin Vennie-Vollrath - 5136'
#  'Ashley Gingeleski - 6858' 'Heather E. Maranville - 7193'
#  'Jennifer Dean - Admin - 2323' 'Julia Roellke - 7470'
#  'Brent Boscarino - 4691' 'Nicole Sedran - 6453' 'Leah Gorman - 5069'
#  'Lars Rudstam - 8544' 'Matt Brincka - 3837' 'Robert Vasiluth - 8900'
#  'Tarki Heath - 4556' 'Karen Riva_Murray - 3344' 'Public Reports - 6034']
# ['Alex Parry - 9741' 'Ryan Fordham - 9731' 'Alaina Oughterson - 9744'
#  'Jessie Dixon - 8580' 'Luke Gervase - 9596' 'Jessica Ingham - 8025'
#  'Tyler Levy - 9838' 'Walter Dutcher - 4296' 'Tim Rice - 9742'
#  'Kristopher Williams - 9274' 'Brittney Rogers - 4361'
#  'David Andrews - 9471' 'Sarah Whitney - 12557' 'Brooke Pegher - 12592'
#  'Mary Walsh - 12415' 'Mary Walsh - 12422' 'Milt Ostrofsky - 12744'
#  'Eric Chapman - 12691' 'Robert Dillon - 12748'
#  'Collector unknown - 12539' 'Mark Lethaby - 12659' 'Tim Daley - 12790'
#  'Steven Adams - 12611' 'Jim Grazio - 12566' 'John Wallace - 12932'
#  'Representative from iNaturalist.org - 12903' 'Peter Woods - 12738'
#  'David Yeany - 12756' 'Brian Mangan - 13235' 'Aaron Jewitt - 13223']
# ['Daniel Nydick - 12749' 'Nick Macelko - 13476' 'Kevin Kelly - 12671'
#  'Christopher Tracey - 12740' 'Elizabeth Meyer - 12759'
#  'Amy Jewitt - 12931' 'Dave Rebuck - 12770' 'Rick Spear - 12773'
#  'Amy Williams - 12792' 'David Lieb - 12817' 'USGS-NAS Database - 13574'
#  'Steven Pearson - 9597' 'Jared Parsons - 16066'
#  'David  Lindeman  - 16548' 'Kathryn Monacelli - 5479'
#  'Cora Delucia - 16025' 'Emma Antolos - 4466' 'Josh Neff - 7926'
#  'Matthew Shank - 12575' 'Kyle Thaine - 16074' 'Kristen Holeck - 17825'
#  'Kristen Wilde - 6989' 'Lindsay Yoder - 9580' 'Jeffrey Burt - 18425'
#  'Andrew Turner - 12602' 'Nick Decker - 13177' 'Marc Hecht - 19784'
#  'Elizabeth Bradshaw - 19635' 'Bianca Gonzalez - 15848'
#  'Melissa Foucreau - 19636']
# ['Winston Gedicks - 9521' 'Catherine McGlynn - 2332'
#  'Jacob Cramer - 16387' 'Emma Stanczyk - 21290' 'Sean Hartzell - 21318'
#  'Sarah Coney - 8462' 'Lauren Henderson - 19154' 'Alexander Krest - 19533'
#  'Sequoia Sempervirens - 21973' 'Ty Sharrow - 20699'
#  'Zachary Pryor - 22185' 'Andrew Conboy - 20713' 'Alicia Palmer - 14331'
#  'APIPP Data Recorder - 19322' 'Phil Cwiek - 23358'
#  'Rebecca Hargrave - 2569' 'Lynne Beaty - 22966' 'Tyler Grabowski - 23959'
#  'Sam Verbeck - 23775' 'Vara Connor - 22874' 'Les Resseguie - 18751'
#  'Robert S. Whyte - 13887' 'Mark Brickner - 12782' 'Bob Mozer - 11264'
#  'Adele Philippides - 21025' 'STEPHEN Miller - 23860'
#  'Colleen Lutz - 5591' 'Sarah Pawliczak - 25355' 'Alejandro Reyes - 3777'
#  'Brian Greene - 23174']
# ['Brandon Russell - 25077' 'Maya Thompson - 23610'
#  'Abigail Bezrutczyk - 8887' 'Mark Privee - 22873' 'Josh Young - 26421'
#  'Jared Ortlieb - 27124' 'Joshua Dipaola - 24140' 'Eric Schill - 22075'
#  'Chris Leece - 19349' 'Abby Webster - 28441' 'Kimberly Schulz - 8779'
#  'Stacy Furgal - 3099' 'Sierra Stickney - 28620' 'Monica Groth - 23793'
#  'Strike Team Technician - 28619' 'Carolyn Cyr - 22588'
#  'Caleb Lines - 28775' 'NYNJTC Aquatic Invasives Strike Force - 23520'
#  'Diego Diaz - 28777' 'Devin DiGiacopo - 27768' 'Rachel Kester - 33029'
#  'Brea Arvidson - 19275' 'Gregory Lech - 13213' 'Mike Campbell - 32609'
#  'Tammara Van Ryn - 19561' 'Megan Kirby - 28868' 'Matthew Gorman - 28948'
#  'Michael Spada - 11092' 'Alisa Trudell - 28780' 'Rosie Grayburn - 35270']
# ['Eileen Fitzgerald - 35466' 'Douglas Wessells - 36323'
#  'Toland Kister - 36646' 'Julia  Luna  - 28958' 'Hannah Coppola - 21052'
#  'Lauren Mercier - 10563' 'Gage Root - 32360' 'Kirby Van Vleet - 20292'
#  'Julian Motola - 20913' 'Erica Kaczmarczyk - 37464' 'Noah Yawn - 32977'
#  'Caitlin Canario - 23811' 'Christopher  Titus - 37897'
#  'chris pennuto - 4422' 'Katherine Lawson - 37416'
#  'Meredith Taylor - 2488' 'Hannah Diebboll - 37153' 'Tyler Smith - 2085'
#  'Rachel Sysak - 3599' 'Scott Kishbaugh - 2262' 'Steven P. Grund - 12449'
#  'iNaturalist User - 12134' 'Jason Jakielaszek - 33030'
#  'Dana Holmlund - 32627']
# <ipython-input-43-2b88d9cce6af>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rdf.rename(columns={'present_species_id':'uid', "scientific_name":"sci_name", "observation_date":"obs_date"}, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# <ipython-input-43-2b88d9cce6af>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rdf.drop(['geometry', 'observer_name', 'jurisdiction', 'genus'], axis=1, inplace=True)
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# intersect pseudoobs with lakes
import geopandas as gpd
# lake polygone
if lakes is None:
  lakes = gpd.read_file("/content/drive/My Drive/iedrr/NHDWaterbody_V2_LakePondReservoir_GLStates.json")
  print(lakes.crs)
  utm = lakes.estimate_utm_crs()
  lakes = lakes.to_crs(utm)
  print(lakes.crs)

imap_abs = {}

for i, (k, v) in enumerate(my_vars.items()):
  print(k)
  if type(imap_recorders[k]) == list:
    continue
  else:
    gdf = gpd.GeoDataFrame(imap_recorders[k], geometry=gpd.points_from_xy(imap_recorders[k]['lon_dec'], imap_recorders[k]['lat_dec']), crs="EPSG:4326")
    gdf = gdf.to_crs(utm)
    print(gdf.crs)
    print(len(imap_recorders[k]))

    buffer_distance = 500  # meters

    # Create a buffer around each point

    joined_lakes = gpd.sjoin(lakes, gdf, predicate='dwithin', distance=buffer_distance)

    joined_lakes = joined_lakes.dropna(subset='obs_date')
    joined_lakes.reset_index(drop=True,inplace=True)

    imap_abs[k] = joined_lakes[['Permanent_', 'obs_date']]
# Out:
# fish
# EPSG:32616
# 1964
# plant
# EPSG:32616
# 453
# invert
# EPSG:32616
# 4192

# %% [markdown]
# # EDDMapS

# %%
from google.colab import userdata
import requests
import json
from pandas import json_normalize

edd_obs = {}

# log in to EDDMapS API
s = requests.session()

login_url = 'https://api.bugwoodcloud.org/v2/login'
headers = {
    "accept": "application/json",
    "Content-Type": "application/json"
}
resp = s.post(login_url, headers=headers, json={"email": userdata.get('EDDMAPS_USER'), "password": userdata.get('EDDMAPS_PWD')})

# resp.raise_for_status()

# can't search occurrence data using scientific names directly, have to get IDs first
subj_url = "https://api.bugwoodcloud.org/v2/subject"
sparams = dict()
sparams["searchon"] = "ScientificName"

for i, (k, v) in enumerate(my_vars.items()):
  print("starting ",k)

  namelist = []

  splist = v['sci_name'].sum() # make list of all species inc. alternate scientific names

  for name in splist:
    #print(name)
    # have to drop space between genus and species
    name = name.replace(" ", "")
    sparams["search"] = name
    r = s.get(subj_url, params=sparams)

    if r.status_code == 200:
      # Parse the JSON response
      data = json.loads(r.text)
      df = json_normalize(data)
      if df.empty:
        print("No results for",name)
        continue
      else:
        # specify fields to extract
        subfields = ["subjectid", "namepart1", "namepart2"]
        df = df[subfields]
        # clean up extra taxa that contain snakehead genus name
        if k == "fish":
          mask = df[df.apply(lambda row: row.str.contains('channa', case=False).any(), axis=1)]
          if not mask.empty:
            mask = mask.loc[mask['namepart1'] != "Channa"]
            df = pd.merge(df,mask, indicator=True, how='outer') \
              .query('_merge=="left_only"') \
              .drop('_merge', axis=1)
        #print (df)
        namelist.append(df)

    else:
        print("Error: ", r.status_code)

  namelist = pd.concat(namelist, ignore_index=True)

  subjs = ','.join(namelist['subjectid'].astype(str)) #comma-separated list of subject ids for species of interest

  # get occurrence data
  occ_url = 'https://api.bugwoodcloud.org/v2/occurrence'
  params = dict()
  params["subjectid"] = subjs
  # "scientificname" is not a valid param, need to use subjectids
  params["sortorder"] = "desc"
  params["enddate"] = "01/17/2025"
  params["startdate"] = "01/01/1970"
  params["paging"] = "false"

  statedfs = []

  for state in ["17","18","26","27","36","39","42","55"]: # FIPS codes for IL, IN, MI, MN, NY, OH, PA, WI
    params["state"] = state
    r2 = s.get(occ_url, params=params) # is there a limit to number of records?

    # Check if the request was successful
    if r2.status_code == 200:
      # Parse the JSON response
      data = json.loads(r2.text)
      df = json_normalize(data)
      # specify fields to extract
      subfields = ["objectid", "scientificname", "observationdate", "latitude_decimal", "longitude_decimal", "recordbasis", "identificationcredibility"]
      if not df.empty:
        df = df[subfields]
        statedfs.append(df)
      else:
        print("No ",k," results for ",state)

    else:
        print("Error: ", r.status_code)

  cdf = pd.concat(statedfs, ignore_index=True)
  # QAQC
  cdf = cdf[cdf.recordbasis != "Preserved Specimen"]
  keeps = ["Credible", "Verified"]
  cdf = cdf[cdf['identificationcredibility'].isin(keeps)]
  cdf.dropna(inplace=True)
  cdf.reset_index(drop=True,inplace=True)
  cdf.drop(['recordbasis', 'identificationcredibility'], axis=1, inplace=True)
  cdf.rename(columns={'objectid':'uid', "scientificname":"sci_name", "observationdate":"obs_date", "latitude_decimal":"lat_dec", "longitude_decimal":"lon_dec"}, inplace=True)
  cdf["source"] = "EDDMapS"
  cdf['uid'] = cdf['uid'].astype(str)
  cdf['obs_date'] = pd.to_datetime(cdf['obs_date'])
  print (cdf.shape[0],k," records")

  edd_obs[k] = cdf
# Out:
# starting  fish
# No  fish  results for  39
# No  fish  results for  42
# 25 fish  records
# starting  plant
# No results for Pontederiaazurea
# 44 plant  records
# starting  invert
# 50 invert  records

# %% [markdown]
# # Combine

# %%
# is there a lake within a km of the obs
# !pip install pynhd

import shapely
import folium
import matplotlib

from pynhd import HP3D, NLDI, WaterData, NHDPlusHR, NHD

nhd3d = HP3D("waterbody")
nhdp_wb = WaterData("nhdwaterbody")
nhdp_mr = WaterData("nhdflowline_network")
# pynhd.pynhd.NHD has waterbody_hr but only WaterData has bydistance function
eck4 = "+proj=eck4 +lon_0=0 +x_0=0 +y_0=0 +datum=WGS84 +units=m +no_defs"
rad = 5e2 # find reaches within 500 m
# Out:
# Collecting pynhd
#   Downloading pynhd-0.19.0-py3-none-any.whl.metadata (25 kB)
# Collecting async-retriever<0.20,>=0.19 (from pynhd)
#   Downloading async_retriever-0.19.1-py3-none-any.whl.metadata (16 kB)
# Collecting cytoolz (from pynhd)
#   Downloading cytoolz-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: geopandas>=1 in /usr/local/lib/python3.11/dist-packages (from pynhd) (1.0.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pynhd) (3.4.2)
# Collecting numpy>=2 (from pynhd)
#   Downloading numpy-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.11/dist-packages (from pynhd) (2.2.2)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pynhd) (17.0.0)
# Collecting pygeoogc<0.20,>=0.19 (from pynhd)
#   Downloading pygeoogc-0.19.0-py3-none-any.whl.metadata (18 kB)
# Collecting pygeoutils<0.20,>=0.19 (from pynhd)
#   Downloading pygeoutils-0.19.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: shapely>=2 in /usr/local/lib/python3.11/dist-packages (from pynhd) (2.0.7)
# Collecting aiodns (from async-retriever<0.20,>=0.19->pynhd)
#   Downloading aiodns-3.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting aiofiles (from async-retriever<0.20,>=0.19->pynhd)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp-client-cache>=0.12.3 (from async-retriever<0.20,>=0.19->pynhd)
#   Downloading aiohttp_client_cache-0.12.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: aiohttp>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from async-retriever<0.20,>=0.19->pynhd) (3.11.12)
# Collecting aiosqlite (from async-retriever<0.20,>=0.19->pynhd)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting brotli (from async-retriever<0.20,>=0.19->pynhd)
#   Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from async-retriever<0.20,>=0.19->pynhd) (1.6.0)
# Collecting ujson (from async-retriever<0.20,>=0.19->pynhd)
#   Downloading ujson-5.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1->pynhd) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas>=1->pynhd) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1->pynhd) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->pynhd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->pynhd) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->pynhd) (2025.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (0.7.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (1.4.2)
# Requirement already satisfied: multidict in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (6.1.0)
# Collecting owslib>=0.27.2 (from pygeoogc<0.20,>=0.19->pynhd)
#   Downloading OWSLib-0.32.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (2.32.3)
# Requirement already satisfied: requests-cache>=0.9.6 in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (1.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (4.12.2)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (1.4.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (2.3.0)
# Requirement already satisfied: yarl in /usr/local/lib/python3.11/dist-packages (from pygeoogc<0.20,>=0.19->pynhd) (1.18.3)
# Collecting netcdf4 (from pygeoutils<0.20,>=0.19->pynhd)
#   Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting rasterio>=1.2 (from pygeoutils<0.20,>=0.19->pynhd)
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting rioxarray>=0.11 (from pygeoutils<0.20,>=0.19->pynhd)
#   Downloading rioxarray-0.18.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pygeoutils<0.20,>=0.19->pynhd) (1.13.1)
# Requirement already satisfied: xarray>=2023.1 in /usr/local/lib/python3.11/dist-packages (from pygeoutils<0.20,>=0.19->pynhd) (2025.1.2)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from cytoolz->pynhd) (0.12.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.3->async-retriever<0.20,>=0.19->pynhd) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.3->async-retriever<0.20,>=0.19->pynhd) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.3->async-retriever<0.20,>=0.19->pynhd) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.3->async-retriever<0.20,>=0.19->pynhd) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.3->async-retriever<0.20,>=0.19->pynhd) (0.2.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp-client-cache>=0.12.3->async-retriever<0.20,>=0.19->pynhd) (2.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from owslib>=0.27.2->pygeoogc<0.20,>=0.19->pynhd) (5.3.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from owslib>=0.27.2->pygeoogc<0.20,>=0.19->pynhd) (6.0.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas>=1->pynhd) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1->pynhd) (1.17.0)
# Collecting affine (from rasterio>=1.2->pygeoutils<0.20,>=0.19->pynhd)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio>=1.2->pygeoutils<0.20,>=0.19->pynhd) (8.1.8)
# Collecting cligj>=0.5 (from rasterio>=1.2->pygeoutils<0.20,>=0.19->pynhd)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio>=1.2->pygeoutils<0.20,>=0.19->pynhd)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio>=1.2->pygeoutils<0.20,>=0.19->pynhd) (3.2.1)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache>=0.9.6->pygeoogc<0.20,>=0.19->pynhd) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache>=0.9.6->pygeoogc<0.20,>=0.19->pynhd) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pygeoogc<0.20,>=0.19->pynhd) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pygeoogc<0.20,>=0.19->pynhd) (3.10)
# Collecting pycares>=4.0.0 (from aiodns->async-retriever<0.20,>=0.19->pynhd)
#   Downloading pycares-4.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting cftime (from netcdf4->pygeoutils<0.20,>=0.19->pynhd)
#   Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from pycares>=4.0.0->aiodns->async-retriever<0.20,>=0.19->pynhd) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns->async-retriever<0.20,>=0.19->pynhd) (2.22)
# Downloading pynhd-0.19.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 4.0 MB/s eta 0:00:00
# Downloading async_retriever-0.19.1-py3-none-any.whl (17 kB)
# Downloading numpy-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 74.7 MB/s eta 0:00:00
# Downloading pygeoogc-0.19.0-py3-none-any.whl (34 kB)
# Downloading pygeoutils-0.19.0-py3-none-any.whl (30 kB)
# Downloading cytoolz-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 70.4 MB/s eta 0:00:00
# Downloading aiohttp_client_cache-0.12.4-py3-none-any.whl (32 kB)
# Downloading OWSLib-0.32.1-py2.py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.1/240.1 kB 18.5 MB/s eta 0:00:00
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 39.7 MB/s eta 0:00:00
# Downloading rioxarray-0.18.2-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 5.3 MB/s eta 0:00:00
# Downloading aiodns-3.2.0-py3-none-any.whl (5.7 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 72.2 MB/s eta 0:00:00
# Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 92.9 MB/s eta 0:00:00
# Downloading ujson-5.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.0 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading pycares-4.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.6/288.6 kB 21.3 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.3 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: brotli, ujson, numpy, cytoolz, cligj, click-plugins, aiosqlite, aiofiles, affine, rasterio, pycares, owslib, cftime, netcdf4, aiohttp-client-cache, aiodns, rioxarray, async-retriever, pygeoutils, pygeoogc, pynhd
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytensor 2.27.1 requires numpy<2,>=1.17.0, but you have numpy 2.2.3 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.3 which is incompatible.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.2.3 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.3 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.2.3 which is incompatible.
# langchain 0.3.19 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 2.2.3 which is incompatible.
# Successfully installed affine-2.4.0 aiodns-3.2.0 aiofiles-24.1.0 aiohttp-client-cache-0.12.4 aiosqlite-0.21.0 async-retriever-0.19.1 brotli-1.1.0 cftime-1.6.4.post1 click-plugins-1.1.1 cligj-0.7.2 cytoolz-1.0.1 netcdf4-1.7.2 numpy-2.2.3 owslib-0.32.1 pycares-4.5.0 pygeoogc-0.19.0 pygeoutils-0.19.0 pynhd-0.19.0 rasterio-1.4.3 rioxarray-0.18.2 ujson-5.10.0

# %%
import numpy as np
# !pip install pygris
import pygris
from sklearn.cluster import AgglomerativeClustering

# %%
count_lists = []
for k in my_vars:
  print(k)
  # combine obs from all sources that you ran the code for
  dflist = []
  try:
    dflist.append(gbif_obs[k])
  except:
    pass
  try:
    dflist.append(glansis_obs[k])
  except:
    pass
  try:
    dflist.append(imap_obs[k])
  except:
    pass
  try:
    dflist.append(edd_obs[k])
  except:
    pass
  try:
    dflist.append(misin_obs[k])
  except:
    pass
  for x in dflist:
    if pd.api.types.is_dtype_equal(x['obs_date'].dtype, "datetime64[ns, UTC]"):
      x['obs_date'] = x['obs_date'].dt.tz_localize(None)
    x['obs_date'] = x['obs_date'].dt.normalize()
    #print(x['obs_date'].dtype)
  df = pd.concat(dflist, ignore_index=True)
  df.reset_index(drop=True, inplace=True)

  # use consistent scientific name for Brazilian waterweed, water hyacinths todo: generalize this
  df.replace({'sci_name':{'Elodea densa':'Egeria densa', 'Eichhornia crassipes':'Pontederia crassipes', 'Eichhornia azurea':'Pontederia azurea'}}, inplace = True)

  # final QAQC before counts
  #drop observations whose coordinates are the location of an institution
  rcnt = df.shape[0]
  print(rcnt, " recs before QAQC")
  df["mindist"] = df.apply(calculate_min, axis=1)
  df = df[df["mindist"] > 0.00001] # buffer in degrees
  df.reset_index(drop=True, inplace=True)
  rcnt2 = df.shape[0]
  if rcnt2 < rcnt:
    print(rcnt - rcnt2, " recs at institution lat/longs were dropped")
  # drop obs if lat and long are the same
  df = df[df['lat_dec'] != df['lon_dec']]
  rcnt3 = df.shape[0]
  if rcnt3 < rcnt2:
    print(rcnt2 - rcnt3, " recs where lat = lon were dropped")
  df.dropna(inplace=True)
  rcnt4 = df.shape[0]
  if rcnt4 < rcnt3:
    print(rcnt3 - rcnt4, " recs with nans were dropped")
  print(rcnt4, " recs after QAQC")
  if extent == "states":
  # clip to the Great Lakes states
    import geopandas as gpd
    cwd = os.getcwd()

    # Get US state polygons
    states = pygris.states()
    # Great Lakes states
    states = states[states['NAME'].isin(['Illinois', 'Indiana', 'Michigan', 'Minnesota', 'New York', 'Ohio', 'Pennsylvania', 'Wisconsin'])]

    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['lon_dec'], df['lat_dec']))

    # assume WGS 84 for these point obs, convert to match crs for states
    gdf.set_crs(epsg=4326, inplace=True)
    gdf.to_crs(epsg=4269, inplace=True)

    #Output
    dfGL = gpd.sjoin(gdf, states, predicate='within')
    df = dfGL.drop(['geometry',	'index_right',	'STATEFP',	'STATENS',	'AFFGEOID',	'GEOID',	'STUSPS',	'NAME',	'LSAD',	'ALAND',	'AWATER'], axis=1)
    df.reset_index(drop=True,inplace=True)

  # total recs from each source
  for category, count in df['source'].value_counts().items():
      print(f"{count} total recs from {category}")
      row = [k,category, 'total', count]
      count_lists.append(row)
  # drop duplicates, with a margin of error to account for coordinate rounding

  distance = 0.0001
  xy = df[['lon_dec','lat_dec']].values.tolist()
  cluster = AgglomerativeClustering(n_clusters=None, linkage='single', metric='euclidean', distance_threshold=distance)
  cluster.fit(xy)
  df['group'] = cluster.labels_

  # combine group id, species, date into one microgroup column
  cols = ['group', 'sci_name', 'obs_date']
  df['microgroup'] = df[cols].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)
  # Create a new column with the count of each microgroup
  # if count(microgroup)>1, mark as duplicate
  df['mg_count'] = df.groupby('microgroup')['microgroup'].transform('count')
  df['is_duplicate'] = df['mg_count'] > 1
  # how many recs does each source have that aren't in the other sources
  dfu = df[df['is_duplicate'] != True]
  for category, count in dfu['source'].value_counts().items():
      print(f"{count} unique recs from {category}")
      row = [k,category, 'unique', count]
      count_lists.append(row)
  print(df['is_duplicate'].value_counts())
  print('unique recs: ',df['microgroup'].nunique())
  # Within each microgroup keep the first version of that observation
  df = df.groupby('microgroup', as_index=False).first()
  df.reset_index(drop=True,inplace=True)
  df.drop(['group', 'microgroup', 'mg_count', 'mindist', 'is_duplicate'], axis=1, inplace=True)

  df["taxon"] = k
  # export final obs table for taxon to Drive folder
  cwd = os.getcwd()
  outfile = os.path.join(cwd, k + '_obs_allsources_' + extent + datetime.date.today().strftime('%Y%m%d') + '.csv')
  df.to_csv(outfile, index=False)
  print("exported to ",outfile)


# save total and unique observation counts for each source
count_headers = ['taxon','source', 'type', 'count']
counts_df = pd.DataFrame(count_lists,columns=count_headers)
#counts_df = counts_df.to_frame().reset_index()
allcounts = os.path.join(cwd, 'obs_counts_by_taxon_and_source_' + extent + datetime.date.today().strftime('%Y%m%d') + '.csv')
counts_df.to_csv(allcounts, index=False)

counts_df.drop(['taxon'], axis=1, inplace=True)

counts_df = counts_df.groupby(['source', 'type'])['count'].sum()
counts_df = counts_df.to_frame().reset_index()

counts_df = counts_df.sort_values(by=['source', 'type'])
countfile = os.path.join(cwd, 'obs_counts_by_source_' + datetime.date.today().strftime('%Y%m%d') + '.csv')
counts_df.to_csv(countfile, index=False)
# drop GBIF exports to save space
# !rm -rf ./invert_gbif_obs/
# !rm -rf ./plant_gbif_obs/
# !rm -rf ./fish_gbif_obs/
print("done!")
# Out:
# fish
# 26587  recs before QAQC
# 26587  recs after QAQC
# Using the default year of 2021
# 2677 total recs from GBIF
# 2276 total recs from GLANSIS
# 2002 total recs from MISIN
# 1939 total recs from iMapInvasives
# 1420 unique recs from GBIF
# 1304 unique recs from iMapInvasives
# 814 unique recs from GLANSIS
# 458 unique recs from MISIN
# is_duplicate
# True     4898
# False    3996
# Name: count, dtype: int64
# unique recs:  6031
# exported to  /content/drive/MyDrive/iedrr/speciesobs_20250127/fish_obs_allsources_states20250223.csv
# plant
# 68897  recs before QAQC
# 68897  recs after QAQC
# Using the default year of 2021
# 32110 total recs from iMapInvasives
# 11220 total recs from MISIN
# 9277 total recs from GBIF
# 4202 total recs from GLANSIS
# 23329 unique recs from iMapInvasives
# 4154 unique recs from MISIN
# 3022 unique recs from GBIF
# 270 unique recs from GLANSIS
# is_duplicate
# False    30775
# True     26034
# Name: count, dtype: int64
# unique recs:  41051
# exported to  /content/drive/MyDrive/iedrr/speciesobs_20250127/plant_obs_allsources_states20250223.csv
# invert
# 23121  recs before QAQC
# 1  recs at institution lat/longs were dropped
# 23120  recs after QAQC
# Using the default year of 2021
# 4363 total recs from iMapInvasives
# 3722 total recs from GBIF
# 3606 total recs from MISIN
# 3040 total recs from GLANSIS
# 3015 unique recs from GBIF
# 2626 unique recs from iMapInvasives
# 2154 unique recs from MISIN
# 981 unique recs from GLANSIS
# is_duplicate
# False    8776
# True     5955
# Name: count, dtype: int64
# unique recs:  10964
# exported to  /content/drive/MyDrive/iedrr/speciesobs_20250127/invert_obs_allsources_states20250223.csv
# done!

# %%
# combine potential pseudoabs lakes
cwd = os.getcwd()

for k in my_vars:
  print(k)
  # combine obs from all sources
  plist = [pabs[k], misin_abs[k], imap_abs[k]]

  for x in plist:
    if pd.api.types.is_dtype_equal(x['obs_date'].dtype, "datetime64[ns, UTC]"):
      x['obs_date'] = x['obs_date'].dt.tz_localize(None)
    x['obs_date'] = x['obs_date'].dt.normalize()
    #print(x['obs_date'].dtype)
  df = pd.concat(plist, ignore_index=True)
  df.reset_index(drop=True, inplace=True)
  df.dropna(inplace=True)

  outfile = os.path.join(cwd, k+'_potential_pseudoabs_lakes' + datetime.date.today().strftime('%Y%m%d') + '.csv')
  df.to_csv(outfile, index=False)
# Out:
# fish
# plant
# invert
# <ipython-input-63-2117b76c5841>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['obs_date'] = x['obs_date'].dt.normalize()
